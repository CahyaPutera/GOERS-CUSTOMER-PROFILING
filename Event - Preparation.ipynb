# %% [markdown]
# ## IMPORT LIBRARIES

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import re

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## OVERVIEW

# %%
df = pd.read_csv('dataset\evnts.csv')

# %%
df.head(3)
# Out:
#                                              user_id  \
# 0  4f3e46a6e94452b566553485b619d2f305bd9d875d4f6d...
# 1  23c44b20dafb34672868945ce6428ead219eb8bb5312c5...
# 2  23c44b20dafb34672868945ce6428ead219eb8bb5312c5...
#
#                                             event_id  \
# 0  6629d5a73302852ef915dbda22fa1994213eb36e41c893...
# 1  6629d5a73302852ef915dbda22fa1994213eb36e41c893...
# 2  6629d5a73302852ef915dbda22fa1994213eb36e41c893...
#
#                                      organization_id     transaction_date  \
# 0  9bace67f3bda20854668f8b8a6756d2541c6ec49223803...  2019-01-01 03:04:32
# 1  9bace67f3bda20854668f8b8a6756d2541c6ec49223803...  2019-01-01 03:11:44
# 2  9bace67f3bda20854668f8b8a6756d2541c6ec49223803...  2019-01-01 03:11:50
#
#   event_type organization_type  \
# 0      Event   Event Organizer
# 1      Event   Event Organizer
# 2      Event   Event Organizer
#
#                                       event_category   user_type  \
# 0  Art Exhibition - Family - Art - Exhibition - G...       Guest
# 1  Art Exhibition - Family - Art - Exhibition - G...  Registered
# 2  Art Exhibition - Family - Art - Exhibition - G...  Registered
#
#   user_location event_location  gender  age_when_register   price  \
# 0           NaN        Jakarta    none                NaN   75000
# 1           NaN        Jakarta  female               29.0  100000
# 2           NaN        Jakarta  female               29.0  100000
#
#    total_ticket_sold
# 0                  2
# 1                  1
# 2                  1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54032 entries, 0 to 54031
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            54032 non-null  object
#  1   event_id           54032 non-null  object
#  2   organization_id    54032 non-null  object
#  3   transaction_date   54032 non-null  object
#  4   event_type         54032 non-null  object
#  5   organization_type  54032 non-null  object
#  6   event_category     54026 non-null  object
#  7   user_type          53979 non-null  object
#  8   user_location      9166 non-null   object
#  9   event_location     54026 non-null  object
#  10  gender             50205 non-null  object
#  11  age_when_register  22228 non-null  float64
#  12  price              54032 non-null  int64
#  13  total_ticket_sold  54032 non-null  int64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 5.8+ MB

# %%
pd.DataFrame({'dataFeatures' : df.columns, 'dataType' : df.dtypes.values, 
              'null' : [df[i].isna().sum() for i in df.columns],
              'nullPct' : [((df[i].isna().sum()/len(df[i]))*100).round(1) for i in df.columns],
              'Nunique' : [df[i].nunique() for i in df.columns],
              'uniqueSample' : [list(pd.Series(df[i].unique()).sample()) for i in df.columns]}).reset_index(drop = True)
# Out:
#          dataFeatures dataType   null  nullPct  Nunique  \
# 0             user_id   object      0      0.0    32178
# 1            event_id   object      0      0.0      811
# 2     organization_id   object      0      0.0      274
# 3    transaction_date   object      0      0.0    49308
# 4          event_type   object      0      0.0        1
# 5   organization_type   object      0      0.0        7
# 6      event_category   object      6      0.0      296
# 7           user_type   object     53      0.1        2
# 8       user_location   object  44866     83.0       34
# 9      event_location   object      6      0.0       23
# 10             gender   object   3827      7.1        3
# 11  age_when_register  float64  31804     58.9       60
# 12              price    int64      0      0.0      119
# 13  total_ticket_sold    int64      0      0.0       47
#
#                                          uniqueSample
# 0   [241637b050ea7ad605072a056a49506c7cc96a6416165...
# 1   [160b8561b0489f54d7bee7fefea388357e5acc1db657c...
# 2   [1a0317b905124a447f5bbc88a2d3e83eb9e988671f593...
# 3                               [2020-05-04 15:24:47]
# 4                                             [Event]
# 5                                   [Event Organizer]
# 6                    [Webinar - Networking - Seminar]
# 7                                             [Guest]
# 8                                       [Probolinggo]
# 9                                         [Palembang]
# 10                                              [nan]
# 11                                             [49.0]
# 12                                           [419000]
# 13                                              [100]

# %%
df.describe().T
# Out:
#                      count          mean            std  min   25%   50%  \
# age_when_register  22228.0     24.080079       8.330055  0.0  18.0  22.0
# price              54032.0  82539.488729  310605.878561  0.0   0.0   0.0
# total_ticket_sold  54032.0      1.623556       2.734496  1.0   1.0   1.0
#
#                        75%        max
# age_when_register     29.0      120.0
# price              70000.0  8100000.0
# total_ticket_sold      1.0      134.0

# %%
df.describe(include = 'object').T
# Out:
#                    count unique  \
# user_id            54032  32178
# event_id           54032    811
# organization_id    54032    274
# transaction_date   54032  49308
# event_type         54032      1
# organization_type  54032      7
# event_category     54026    296
# user_type          53979      2
# user_location       9166     34
# event_location     54026     23
# gender             50205      3
#
#                                                                  top   freq
# user_id            74b15dc9dd3a61432731b8edd5588b6cb35ac12ba720d9...    804
# event_id           9441a919384943d46915a2efaaad637bb0ca08cf0de0d9...   4397
# organization_id    1af57e2c0b4cd813117b114b25c36938b219e172830653...   4413
# transaction_date                                 2020-05-22 13:56:48     31
# event_type                                                     Event  54032
# organization_type                       Event Organizer and Promotor  26751
# event_category                                               Webinar   5619
# user_type                                                      Guest  30854
# user_location                                                Jakarta   5577
# event_location                                               Jakarta  25347
# gender                                                          none  23868

# %% [markdown]
# ## PREPROCESSING

# %% [markdown]
# > First we start by fixing the **event_category**.

# %%
df[df['event_category'].isna()]
# Out:
#                                                  user_id  \
# 21800  20f1f78d5eb02b09a503b26e7294399b6b7b3ca7d1565f...
# 21920  d706ae4c83455692d099e6255583f51bcaee466c01b602...
# 23056  5a5bad93c516903217429296f41e7c72b270159da54da5...
# 45189  7c6a0a99b02e47badc12b2f4ac52db93a5d8c789986912...
# 45190  1b710ade9432a036d79a44bf79368326b21919b6973616...
# 45191  917378748f44c1b205af7a0eaa97c8e049857931c25b2e...
#
#                                                 event_id  \
# 21800  83cadc8cf1544e253e3e75fdf140d38badbc1461124e4b...
# 21920  a51ab54c9c7394a052dc73b3adc164af628dcb1049e759...
# 23056  a51ab54c9c7394a052dc73b3adc164af628dcb1049e759...
# 45189  a51ab54c9c7394a052dc73b3adc164af628dcb1049e759...
# 45190  a51ab54c9c7394a052dc73b3adc164af628dcb1049e759...
# 45191  a51ab54c9c7394a052dc73b3adc164af628dcb1049e759...
#
#                                          organization_id     transaction_date  \
# 21800  bf98663c9884ad409695575399cd63a9caf2217c742ae7...  2020-02-15 06:08:50
# 21920  bd3e4020cae3d9d7e8817cd8fdbf351b59faaf02a150fd...  2020-02-17 09:41:04
# 23056  bd3e4020cae3d9d7e8817cd8fdbf351b59faaf02a150fd...  2020-04-17 03:09:18
# 45189  bd3e4020cae3d9d7e8817cd8fdbf351b59faaf02a150fd...  2020-04-17 03:09:18
# 45190  bd3e4020cae3d9d7e8817cd8fdbf351b59faaf02a150fd...  2020-04-17 03:09:18
# 45191  bd3e4020cae3d9d7e8817cd8fdbf351b59faaf02a150fd...  2020-04-17 03:09:19
#
#       event_type             organization_type event_category   user_type  \
# 21800      Event  Event Organizer and Promotor            NaN       Guest
# 21920      Event               Event Organizer            NaN  Registered
# 23056      Event               Event Organizer            NaN  Registered
# 45189      Event               Event Organizer            NaN       Guest
# 45190      Event               Event Organizer            NaN       Guest
# 45191      Event               Event Organizer            NaN  Registered
#
#       user_location event_location  gender  age_when_register    price  \
# 21800           NaN            NaN    none                NaN  3750000
# 21920       Jakarta            NaN    male               26.0        0
# 23056       Jakarta            NaN  female               20.0        0
# 45189           NaN            NaN  female                NaN        0
# 45190           NaN            NaN    none                NaN        0
# 45191       Jakarta            NaN  female               22.0        0
#
#        total_ticket_sold
# 21800                  1
# 21920                  1
# 23056                  5
# 45189                  3
# 45190                  2
# 45191                  3

# %% [markdown]
# > As we can see that the missing values are only on two events and belongs to two different organizations. We will fill it by using this information.

# %%
df[df['event_category'].isna()].groupby('event_id')['organization_id'].value_counts()
# Out:
# event_id                                                          organization_id
# 83cadc8cf1544e253e3e75fdf140d38badbc1461124e4b75f6022d97747e8672  bf98663c9884ad409695575399cd63a9caf2217c742ae795bd82268011ef4432    1
# a51ab54c9c7394a052dc73b3adc164af628dcb1049e75912ecfb702b1024cd9a  bd3e4020cae3d9d7e8817cd8fdbf351b59faaf02a150fd6b12a02c914e914fc0    5
# Name: organization_id, dtype: int64

# %%
df[df['event_id']=='a51ab54c9c7394a052dc73b3adc164af628dcb1049e75912ecfb702b1024cd9a']['event_category']
# Out:
# 21920    NaN
# 23056    NaN
# 45189    NaN
# 45190    NaN
# 45191    NaN
# Name: event_category, dtype: object

# %% [markdown]
# > Seems that we cannot rely on **event id**, let's try the **organization id**.

# %%
df[df['organization_id']=='bd3e4020cae3d9d7e8817cd8fdbf351b59faaf02a150fd6b12a02c914e914fc0']['event_category'].value_counts()
# Out:
# Online Event - Webinar                                                              13
# Webinar - Art                                                                       12
# Music                                                                                6
# Travel - Culture - Adventure - Outdoor - Open Trip - Tour Package - Tourism Site     6
# Name: event_category, dtype: int64

# %% [markdown]
# > We can see that using this method, we can get a clearer view on how to fill these values.

# %%
df[df['organization_id']=='bf98663c9884ad409695575399cd63a9caf2217c742ae795bd82268011ef4432']['event_category'].value_counts()
# Out:
# Festival - Music    34
# Music - Concert      5
# Name: event_category, dtype: int64

# %%
# Locate the organization id

event_fill = df[df['organization_id']=='bd3e4020cae3d9d7e8817cd8fdbf351b59faaf02a150fd6b12a02c914e914fc0']
event_fill2 = df[df['organization_id']=='bf98663c9884ad409695575399cd63a9caf2217c742ae795bd82268011ef4432']

# Filling missing event category

event_fill['event_category'] = event_fill['event_category'].fillna('Online Event - Webinar')
event_fill2['event_category'] = event_fill2['event_category'].fillna('Festival - Music')

# %%
event_fills = pd.concat([event_fill, event_fill2])

# %%
# Merging to original dataframe

df.fillna(event_fills, inplace=True)

# %%
df.isna().sum()
# Out:
# user_id                  0
# event_id                 0
# organization_id          0
# transaction_date         0
# event_type               0
# organization_type        0
# event_category           0
# user_type               53
# user_location        44866
# event_location           6
# gender                3827
# age_when_register    31804
# price                    0
# total_ticket_sold        0
# dtype: int64

# %% [markdown]
# > Now moving to **user type** and **user location**.

# %%
df[df['user_type'].isna()]['event_category'].value_counts()
# Out:
# Webinar                                                                                34
# Webinar - Game                                                                         12
# Webinar - Education - Networking - Seminar                                              2
# Webinar - Conference - Education - Networking - Seminar                                 2
# Webinar - Networking - Seminar                                                          1
# Webinar - Conference - Education - Education Expo - Networking - Seminar - Workshop     1
# Webinar - Education                                                                     1
# Name: event_category, dtype: int64

# %%
df[df['event_category']=='Webinar']['user_type'].value_counts()
# Out:
# Guest         3751
# Registered    1834
# Name: user_type, dtype: int64

# %%
df['user_type'].fillna('Guest', inplace=True)

# %%
df.isna().sum()
# Out:
# user_id                  0
# event_id                 0
# organization_id          0
# transaction_date         0
# event_type               0
# organization_type        0
# event_category           0
# user_type                0
# user_location        44866
# event_location           6
# gender                3827
# age_when_register    31804
# price                    0
# total_ticket_sold        0
# dtype: int64

# %% [markdown]
# > Moving to **user location**.

# %%
df.groupby('user_type')['user_location'].value_counts().head(20)
# Out:
# user_type   user_location
# Guest       Yogyakarta          5
#             Bekasi              1
#             Jakarta             1
# Registered  Jakarta          5576
#             Tangerang        1044
#             Bandung           651
#             Depok             520
#             Makassar          368
#             Bekasi            302
#             Yogyakarta        296
#             Surabaya          180
#             Bali               52
#             Medan              25
#             Cirebon            17
#             Malang             17
#             Lampung            14
#             Karawang           12
#             Palembang          12
#             Semarang           12
#             Balikpapan          7
# Name: user_location, dtype: int64

# %%
df[df['user_location'].isna()]['user_type'].value_counts()
# Out:
# Guest         30900
# Registered    13966
# Name: user_type, dtype: int64

# %% [markdown]
# > As we can see, almost all of the **Guest** users are mostly using website to book the ticket, therefore it might cause the system to not record their location, resulted in these missing values. As for the **Registered** users, I think they're might not filled all of their profile page for various reasons. Logically by this theory, I would rather fill these missing values as **'Unknown Location'**. But if we fill all these missing values as **'Unknown Location'**, it would probably distort the data as we can see the missing values in this features are 83% of total data. To mitigate this, I'll try to manually find the location by matching it with their location. It might not help by much, but I think it's better than leave it just as it is.

# %%
# Guest user

loc_guest_isna = df[(df['user_location'].isna()) & (df['user_type']=='Guest')]
loc_guest_notna = df[(df['user_location'].notna()) & (df['user_type']=='Guest')]

# %%
loc_guest_isna.isna().sum()
# Out:
# user_id                  0
# event_id                 0
# organization_id          0
# transaction_date         0
# event_type               0
# organization_type        0
# event_category           0
# user_type                0
# user_location        30900
# event_location           3
# gender                3724
# age_when_register    30887
# price                    0
# total_ticket_sold        0
# dtype: int64

# %%
loc_guest_isna['event_category'].value_counts()
# Out:
# Webinar - Concert - Education                      3937
# Webinar                                            3785
# Workshop                                           2187
# Webinar - Tech Startup                             1882
# Talkshow                                           1241
#                                                    ...
# Webinar - Education - Seminar                         1
# Conference - Festival - Performance                   1
# Sport - Concert - Art - Competition                   1
# Seminar - Workshop - Tech Startup - Education         1
# Music - Concert - Art - Performance - Orchestra       1
# Name: event_category, Length: 242, dtype: int64

# %% [markdown]
# > Notice that in this category, we find that there are many events that categorized as **Webinar**, I think we cannot find the specific location for user who were attending the webinar events as it occured online, therefore I'll try to filter it out using *regular expression* to help pinpoint this problem.

# %%
# Filter the non webinar event 

guest_not_web_isna = loc_guest_isna[(~loc_guest_isna['event_category'].str.contains('Webinar')==True) & (loc_guest_isna['event_location'] != 'Indonesia')]

# %%
guest_not_web_isna.head()
# Out:
#                                              user_id  \
# 0  4f3e46a6e94452b566553485b619d2f305bd9d875d4f6d...
# 3  b1fc4cf5297d6639937d7806cf8ff626e4fdef6548c892...
# 4  1da4ae70dde95b9d83c7586d1af62599cb01c4fc660f63...
# 5  7dddb95cc3da557d3c0b993d4ad148182cdccd5833387e...
# 6  ebee53b4d8aa0e1d82385d191b9a6b27c21125689f99f7...
#
#                                             event_id  \
# 0  6629d5a73302852ef915dbda22fa1994213eb36e41c893...
# 3  6629d5a73302852ef915dbda22fa1994213eb36e41c893...
# 4  6629d5a73302852ef915dbda22fa1994213eb36e41c893...
# 5  6629d5a73302852ef915dbda22fa1994213eb36e41c893...
# 6  42fbc58b0793f7a78da3aed5023efa91bdfbf219963614...
#
#                                      organization_id     transaction_date  \
# 0  9bace67f3bda20854668f8b8a6756d2541c6ec49223803...  2019-01-01 03:04:32
# 3  9bace67f3bda20854668f8b8a6756d2541c6ec49223803...  2019-01-01 03:24:59
# 4  9bace67f3bda20854668f8b8a6756d2541c6ec49223803...  2019-01-01 03:53:11
# 5  9bace67f3bda20854668f8b8a6756d2541c6ec49223803...  2019-01-01 05:12:57
# 6  58b192b21f26e839d98afc2dce1e03e354756c73ed3f57...  2019-01-01 05:13:45
#
#   event_type organization_type  \
# 0      Event   Event Organizer
# 3      Event   Event Organizer
# 4      Event   Event Organizer
# 5      Event   Event Organizer
# 6      Event   Event Organizer
#
#                                       event_category user_type user_location  \
# 0  Art Exhibition - Family - Art - Exhibition - G...     Guest           NaN
# 3  Art Exhibition - Family - Art - Exhibition - G...     Guest           NaN
# 4  Art Exhibition - Family - Art - Exhibition - G...     Guest           NaN
# 5  Art Exhibition - Family - Art - Exhibition - G...     Guest           NaN
# 6                          Wedding Expo - Exhibition     Guest           NaN
#
#   event_location gender  age_when_register  price  total_ticket_sold
# 0        Jakarta   none                NaN  75000                  2
# 3        Jakarta   none                NaN  75000                  6
# 4        Jakarta   none                NaN  75000                  2
# 5        Jakarta   none                NaN  75000                  4
# 6        Jakarta   none                NaN  15000                  2

# %% [markdown]
# > Since event location : **'Indonesia'** are considered as online event, therefore we will filter that too.

# %%
print(len(guest_not_web_isna))
# Out:
# 17907

# %% [markdown]
# > There are 17907 events filtered, hopefully we can reduce this number by filling out with the values in the not missing categories.

# %%
guest_not_web_isna.groupby('event_location')['event_category'].value_counts()
# Out:
# event_location  event_category
# Bali            Tech Startup - Group Activities - Conference                        69
#                 Competition                                                         11
#                 Workshop - Seminar - Festival - Travel                               4
#                 Concert - Music - Festival                                           3
#                 Workshop - Travel - Seminar - Conference                             2
#                                                                                     ..
# Yogyakarta      Music                                                               71
#                 Conference                                                          47
#                 Movies - Bazaar                                                      3
#                 Networking                                                           3
#                 Travel - Education - University Student - Open Trip - Networking     2
# Name: event_category, Length: 205, dtype: int64

# %%
guest_not_web_isna['price'].value_counts().head(5)
# Out:
# 0         8532
# 50000     1330
# 250000     807
# 232000     701
# 175000     682
# Name: price, dtype: int64

# %%
guest_not_web_isna[guest_not_web_isna['price']==0]
# Out:
#                                                  user_id  \
# 157    67de3e9d4e18bdcaa28e43ed01f6f3365b2a80fc13b8df...
# 163    9b2a9add88a0a944f9570ad5fe51dc77f4717bb2ce4681...
# 166    a37a2419d24e21ee4ef278d6b23badc366792f274f76a5...
# 167    9a8759ac98052d967687cceff79e2d89bcedb92e8c76f9...
# 168    a37a2419d24e21ee4ef278d6b23badc366792f274f76a5...
# ...                                                  ...
# 51395  d8b7e30ac3b76f280a6efc8629dc74e9d337fcf4fe273e...
# 51400  7cbd5ca37c4bb7f9989e783279b282a9e982f3e403254e...
# 53506  84b68f07a14a13395b4e5c6c77a6025aa4bc8a538c8149...
# 53529  44985cfad052079d2398b64c70f06127cc74ab3d74f004...
# 53810  051b7b935efb67ef8efa7eaafbbc593d9c593f4fc9c0eb...
#
#                                                 event_id  \
# 157    69def6ad4b68084a98a62b8974a3a8bc06f56982199bac...
# 163    4043c87f9b90f7100a9fec2b3e7e9119d76a1f410a628e...
# 166    69def6ad4b68084a98a62b8974a3a8bc06f56982199bac...
# 167    69def6ad4b68084a98a62b8974a3a8bc06f56982199bac...
# 168    4043c87f9b90f7100a9fec2b3e7e9119d76a1f410a628e...
# ...                                                  ...
# 51395  937bddf6c441aabe01578fb57f35e0774b344fc81d36d1...
# 51400  937bddf6c441aabe01578fb57f35e0774b344fc81d36d1...
# 53506  6776582fb496f1cfb82be60916be60bb735dd028cd2cdb...
# 53529  6776582fb496f1cfb82be60916be60bb735dd028cd2cdb...
# 53810  6776582fb496f1cfb82be60916be60bb735dd028cd2cdb...
#
#                                          organization_id     transaction_date  \
# 157    28471a21135fc8615295eeebb675e09f915e0b8731eb90...  2019-01-04 13:00:31
# 163    28471a21135fc8615295eeebb675e09f915e0b8731eb90...  2019-01-04 13:51:17
# 166    28471a21135fc8615295eeebb675e09f915e0b8731eb90...  2019-01-04 14:34:36
# 167    28471a21135fc8615295eeebb675e09f915e0b8731eb90...  2019-01-04 14:35:48
# 168    28471a21135fc8615295eeebb675e09f915e0b8731eb90...  2019-01-04 14:39:13
# ...                                                  ...                  ...
# 51395  4a3fcfd7c45cffae0a7bb4fa7a39a228b41e57318a4515...  2020-06-01 11:50:01
# 51400  4a3fcfd7c45cffae0a7bb4fa7a39a228b41e57318a4515...  2020-06-01 12:53:30
# 53506  a78539c39f39c635d2a128d26662f3a2af30de53b08a9c...  2020-06-23 03:57:42
# 53529  a78539c39f39c635d2a128d26662f3a2af30de53b08a9c...  2020-06-23 07:02:10
# 53810  a78539c39f39c635d2a128d26662f3a2af30de53b08a9c...  2020-06-26 02:00:20
#
#       event_type             organization_type      event_category user_type  \
# 157        Event               Event Organizer            Workshop     Guest
# 163        Event               Event Organizer  Seminar - Workshop     Guest
# 166        Event               Event Organizer            Workshop     Guest
# 167        Event               Event Organizer            Workshop     Guest
# 168        Event               Event Organizer  Seminar - Workshop     Guest
# ...          ...                           ...                 ...       ...
# 51395      Event  Event Organizer and Promotor    Group Activities     Guest
# 51400      Event  Event Organizer and Promotor    Group Activities     Guest
# 53506      Event               Event Organizer        Tech Startup     Guest
# 53529      Event               Event Organizer        Tech Startup     Guest
# 53810      Event               Event Organizer        Tech Startup     Guest
#
#       user_location event_location  gender  age_when_register  price  \
# 157             NaN       Makassar    none                NaN      0
# 163             NaN       Makassar    none                NaN      0
# 166             NaN       Makassar  female                NaN      0
# 167             NaN       Makassar    none                NaN      0
# 168             NaN       Makassar  female                NaN      0
# ...             ...            ...     ...                ...    ...
# 51395           NaN        Jakarta    none                NaN      0
# 51400           NaN        Jakarta    none                NaN      0
# 53506           NaN     Yogyakarta    male                NaN      0
# 53529           NaN     Yogyakarta    male                NaN      0
# 53810           NaN     Yogyakarta    male                NaN      0
#
#        total_ticket_sold
# 157                    1
# 163                    1
# 166                    1
# 167                    1
# 168                    1
# ...                  ...
# 51395                  4
# 51400                  1
# 53506                  1
# 53529                  1
# 53810                  1
#
# [8532 rows x 14 columns]

# %% [markdown]
# > As we can see, there are 8532 events with **Guest** users. That are *free*. And these events are not considered as **Webinars** or **Online events**, therefore logically it's safe to assume, there are high chance that the location of these users are from the same location of the event held.

# %%
# Filling the user location

loc_guest_isna['user_location'] = guest_not_web_isna['event_location']

# %%
loc_guest_isna.head()
# Out:
#                                              user_id  \
# 0  4f3e46a6e94452b566553485b619d2f305bd9d875d4f6d...
# 3  b1fc4cf5297d6639937d7806cf8ff626e4fdef6548c892...
# 4  1da4ae70dde95b9d83c7586d1af62599cb01c4fc660f63...
# 5  7dddb95cc3da557d3c0b993d4ad148182cdccd5833387e...
# 6  ebee53b4d8aa0e1d82385d191b9a6b27c21125689f99f7...
#
#                                             event_id  \
# 0  6629d5a73302852ef915dbda22fa1994213eb36e41c893...
# 3  6629d5a73302852ef915dbda22fa1994213eb36e41c893...
# 4  6629d5a73302852ef915dbda22fa1994213eb36e41c893...
# 5  6629d5a73302852ef915dbda22fa1994213eb36e41c893...
# 6  42fbc58b0793f7a78da3aed5023efa91bdfbf219963614...
#
#                                      organization_id     transaction_date  \
# 0  9bace67f3bda20854668f8b8a6756d2541c6ec49223803...  2019-01-01 03:04:32
# 3  9bace67f3bda20854668f8b8a6756d2541c6ec49223803...  2019-01-01 03:24:59
# 4  9bace67f3bda20854668f8b8a6756d2541c6ec49223803...  2019-01-01 03:53:11
# 5  9bace67f3bda20854668f8b8a6756d2541c6ec49223803...  2019-01-01 05:12:57
# 6  58b192b21f26e839d98afc2dce1e03e354756c73ed3f57...  2019-01-01 05:13:45
#
#   event_type organization_type  \
# 0      Event   Event Organizer
# 3      Event   Event Organizer
# 4      Event   Event Organizer
# 5      Event   Event Organizer
# 6      Event   Event Organizer
#
#                                       event_category user_type user_location  \
# 0  Art Exhibition - Family - Art - Exhibition - G...     Guest       Jakarta
# 3  Art Exhibition - Family - Art - Exhibition - G...     Guest       Jakarta
# 4  Art Exhibition - Family - Art - Exhibition - G...     Guest       Jakarta
# 5  Art Exhibition - Family - Art - Exhibition - G...     Guest       Jakarta
# 6                          Wedding Expo - Exhibition     Guest       Jakarta
#
#   event_location gender  age_when_register  price  total_ticket_sold
# 0        Jakarta   none                NaN  75000                  2
# 3        Jakarta   none                NaN  75000                  6
# 4        Jakarta   none                NaN  75000                  2
# 5        Jakarta   none                NaN  75000                  4
# 6        Jakarta   none                NaN  15000                  2

# %%
loc_guest_notna
# Out:
#                                                  user_id  \
# 15487  acda42628433d3ace7246178d403f71cf3dd892125f7db...
# 26895  c9d8e3ee303dddf7dbb29da1dd79eea0d21b4e6278c26e...
# 27236  c9d8e3ee303dddf7dbb29da1dd79eea0d21b4e6278c26e...
# 27673  c9d8e3ee303dddf7dbb29da1dd79eea0d21b4e6278c26e...
# 28118  c9d8e3ee303dddf7dbb29da1dd79eea0d21b4e6278c26e...
# 28631  c9d8e3ee303dddf7dbb29da1dd79eea0d21b4e6278c26e...
# 30287  641706ca6b6502c33eda0b99361d99d5886902878cab14...
#
#                                                 event_id  \
# 15487  ea9af3b765d1ca781f3ba325e52cde149e7d7ed98c61fb...
# 26895  9441a919384943d46915a2efaaad637bb0ca08cf0de0d9...
# 27236  9441a919384943d46915a2efaaad637bb0ca08cf0de0d9...
# 27673  9441a919384943d46915a2efaaad637bb0ca08cf0de0d9...
# 28118  9441a919384943d46915a2efaaad637bb0ca08cf0de0d9...
# 28631  9441a919384943d46915a2efaaad637bb0ca08cf0de0d9...
# 30287  552dcd9035c4d520da6318e41c831953b3f84c4a7a9cfc...
#
#                                          organization_id     transaction_date  \
# 15487  ccc11d9b108e2c73c4954d0fc68a56ad0d74e4d175cfde...  2019-10-10 04:49:20
# 26895  1af57e2c0b4cd813117b114b25c36938b219e172830653...  2020-05-20 04:39:54
# 27236  1af57e2c0b4cd813117b114b25c36938b219e172830653...  2020-05-21 04:29:48
# 27673  1af57e2c0b4cd813117b114b25c36938b219e172830653...  2020-05-21 05:52:33
# 28118  1af57e2c0b4cd813117b114b25c36938b219e172830653...  2020-05-21 11:05:36
# 28631  1af57e2c0b4cd813117b114b25c36938b219e172830653...  2020-05-22 13:58:06
# 30287  39d13f95b71eb21f7b80bb1fcc3795548688fd1a8e8f27...  2020-06-12 04:57:02
#
#       event_type             organization_type  \
# 15487      Event  Event Organizer and Promotor
# 26895      Event  Event Organizer and Promotor
# 27236      Event  Event Organizer and Promotor
# 27673      Event  Event Organizer and Promotor
# 28118      Event  Event Organizer and Promotor
# 28631      Event  Event Organizer and Promotor
# 30287      Event  Event Organizer and Promotor
#
#                          event_category user_type user_location  \
# 15487  Music - Art - Festival - Concert     Guest        Bekasi
# 26895     Webinar - Concert - Education     Guest    Yogyakarta
# 27236     Webinar - Concert - Education     Guest    Yogyakarta
# 27673     Webinar - Concert - Education     Guest    Yogyakarta
# 28118     Webinar - Concert - Education     Guest    Yogyakarta
# 28631     Webinar - Concert - Education     Guest    Yogyakarta
# 30287               Webinar - Education     Guest       Jakarta
#
#       event_location gender  age_when_register  price  total_ticket_sold
# 15487         Bekasi   none                NaN      0                  1
# 26895      Indonesia   none                NaN      0                  1
# 27236      Indonesia   none                NaN      0                  1
# 27673      Indonesia   none                NaN      0                  1
# 28118      Indonesia   none                NaN      0                  1
# 28631      Indonesia   none                NaN      0                  1
# 30287      Indonesia   none                NaN      0                  1

# %% [markdown]
# > Even in this categories, we can still see the webinar events are still dominating.

# %%
loc_guest_notna.groupby('event_id')['event_type'].value_counts()
# Out:
# event_id                                                          event_type
# 552dcd9035c4d520da6318e41c831953b3f84c4a7a9cfc79f127c911da52a76a  Event         1
# 9441a919384943d46915a2efaaad637bb0ca08cf0de0d96a19597aa72ba8d6b2  Event         5
# ea9af3b765d1ca781f3ba325e52cde149e7d7ed98c61fb6c1996431588ffeda8  Event         1
# Name: event_type, dtype: int64

# %%
loc_guest_notna.groupby('event_id')['user_location'].value_counts()
# Out:
# event_id                                                          user_location
# 552dcd9035c4d520da6318e41c831953b3f84c4a7a9cfc79f127c911da52a76a  Jakarta          1
# 9441a919384943d46915a2efaaad637bb0ca08cf0de0d96a19597aa72ba8d6b2  Yogyakarta       5
# ea9af3b765d1ca781f3ba325e52cde149e7d7ed98c61fb6c1996431588ffeda8  Bekasi           1
# Name: user_location, dtype: int64

# %%
print('Bekasi ' + str(len(loc_guest_isna[loc_guest_isna['event_id']=='ea9af3b765d1ca781f3ba325e52cde149e7d7ed98c61fb6c1996431588ffeda8']))) # Bekasi
# Out:
# Bekasi 212

# %%
# Locating the event location based on event id

guest_fill = loc_guest_isna[loc_guest_isna['event_id']=='ea9af3b765d1ca781f3ba325e52cde149e7d7ed98c61fb6c1996431588ffeda8']
guest_fill['user_location'] = guest_fill['user_location'].fillna('Bekasi')

# %%
loc_guest_isna['user_location'] = loc_guest_isna['user_location'].fillna(guest_fill['user_location'])

# %%
loc_guest_isna.isna().sum()
# Out:
# user_id                  0
# event_id                 0
# organization_id          0
# transaction_date         0
# event_type               0
# organization_type        0
# event_category           0
# user_type                0
# user_location        12994
# event_location           3
# gender                3724
# age_when_register    30887
# price                    0
# total_ticket_sold        0
# dtype: int64

# %% [markdown]
# > Now moving to registered user. We will use the same method as before.

# %%
# Registered user

loc_regist_isna = df[(df['user_location'].isna()) & (df['user_type']=='Registered')]
loc_regist_notna = df[(df['user_location'].notna()) & (df['user_type']=='Registered')]

# %%
loc_regist_isna['event_category'].value_counts()
# Out:
# Music - Highschool Student - Concert - Pensi                                                                  1810
# Music - Food - Fashion - Festival                                                                             1754
# Webinar                                                                                                       1571
# Music - Concert - Live Music - Pensi                                                                           933
# Music - Concert                                                                                                812
#                                                                                                               ...
# Seminar - Conference - Talkshow - Career Expo                                                                    1
# Webinar - Education - Networking                                                                                 1
# Sport - Concert - Art - Competition                                                                              1
# Webinar - Conference - Education - Networking - Workshop                                                         1
# Webinar - Beauty - Education - Networking - Parenting - Seminar - Talkshow - Workshop - University Student       1
# Name: event_category, Length: 165, dtype: int64

# %%
loc_regist_isna.head(3)
# Out:
#                                              user_id  \
# 1  23c44b20dafb34672868945ce6428ead219eb8bb5312c5...
# 2  23c44b20dafb34672868945ce6428ead219eb8bb5312c5...
# 7  23c44b20dafb34672868945ce6428ead219eb8bb5312c5...
#
#                                             event_id  \
# 1  6629d5a73302852ef915dbda22fa1994213eb36e41c893...
# 2  6629d5a73302852ef915dbda22fa1994213eb36e41c893...
# 7  6629d5a73302852ef915dbda22fa1994213eb36e41c893...
#
#                                      organization_id     transaction_date  \
# 1  9bace67f3bda20854668f8b8a6756d2541c6ec49223803...  2019-01-01 03:11:44
# 2  9bace67f3bda20854668f8b8a6756d2541c6ec49223803...  2019-01-01 03:11:50
# 7  9bace67f3bda20854668f8b8a6756d2541c6ec49223803...  2019-01-01 05:15:37
#
#   event_type organization_type  \
# 1      Event   Event Organizer
# 2      Event   Event Organizer
# 7      Event   Event Organizer
#
#                                       event_category   user_type  \
# 1  Art Exhibition - Family - Art - Exhibition - G...  Registered
# 2  Art Exhibition - Family - Art - Exhibition - G...  Registered
# 7  Art Exhibition - Family - Art - Exhibition - G...  Registered
#
#   user_location event_location  gender  age_when_register   price  \
# 1           NaN        Jakarta  female               29.0  100000
# 2           NaN        Jakarta  female               29.0  100000
# 7           NaN        Jakarta  female               29.0  100000
#
#    total_ticket_sold
# 1                  1
# 2                  1
# 7                  3

# %%
loc_regist_isna.isna().sum()
# Out:
# user_id                  0
# event_id                 0
# organization_id          0
# transaction_date         0
# event_type               0
# organization_type        0
# event_category           0
# user_type                0
# user_location        13966
# event_location           0
# gender                 101
# age_when_register      742
# price                    0
# total_ticket_sold        0
# dtype: int64

# %%
regist_not_web_isna = loc_regist_isna[(~loc_regist_isna['event_category'].str.contains('Webinar')==True) & (loc_regist_isna['event_location']!= 'Indonesia')]

# %%
regist_not_web_isna.head()
# Out:
#                                              user_id  \
# 1  23c44b20dafb34672868945ce6428ead219eb8bb5312c5...
# 2  23c44b20dafb34672868945ce6428ead219eb8bb5312c5...
# 7  23c44b20dafb34672868945ce6428ead219eb8bb5312c5...
# 8  23c44b20dafb34672868945ce6428ead219eb8bb5312c5...
# 9  23c44b20dafb34672868945ce6428ead219eb8bb5312c5...
#
#                                             event_id  \
# 1  6629d5a73302852ef915dbda22fa1994213eb36e41c893...
# 2  6629d5a73302852ef915dbda22fa1994213eb36e41c893...
# 7  6629d5a73302852ef915dbda22fa1994213eb36e41c893...
# 8  6629d5a73302852ef915dbda22fa1994213eb36e41c893...
# 9  6629d5a73302852ef915dbda22fa1994213eb36e41c893...
#
#                                      organization_id     transaction_date  \
# 1  9bace67f3bda20854668f8b8a6756d2541c6ec49223803...  2019-01-01 03:11:44
# 2  9bace67f3bda20854668f8b8a6756d2541c6ec49223803...  2019-01-01 03:11:50
# 7  9bace67f3bda20854668f8b8a6756d2541c6ec49223803...  2019-01-01 05:15:37
# 8  9bace67f3bda20854668f8b8a6756d2541c6ec49223803...  2019-01-01 05:58:08
# 9  9bace67f3bda20854668f8b8a6756d2541c6ec49223803...  2019-01-01 06:22:07
#
#   event_type organization_type  \
# 1      Event   Event Organizer
# 2      Event   Event Organizer
# 7      Event   Event Organizer
# 8      Event   Event Organizer
# 9      Event   Event Organizer
#
#                                       event_category   user_type  \
# 1  Art Exhibition - Family - Art - Exhibition - G...  Registered
# 2  Art Exhibition - Family - Art - Exhibition - G...  Registered
# 7  Art Exhibition - Family - Art - Exhibition - G...  Registered
# 8  Art Exhibition - Family - Art - Exhibition - G...  Registered
# 9  Art Exhibition - Family - Art - Exhibition - G...  Registered
#
#   user_location event_location  gender  age_when_register   price  \
# 1           NaN        Jakarta  female               29.0  100000
# 2           NaN        Jakarta  female               29.0  100000
# 7           NaN        Jakarta  female               29.0  100000
# 8           NaN        Jakarta  female               29.0  100000
# 9           NaN        Jakarta  female               29.0  100000
#
#    total_ticket_sold
# 1                  1
# 2                  1
# 7                  3
# 8                  3
# 9                  5

# %%
len(regist_not_web_isna)
# Out:
# 9768

# %% [markdown]
# > There are 9768 rows of user with unknown location. We will fill it by previously stated logic.

# %%
loc_regist_isna['user_location'] = regist_not_web_isna['event_location']

# %%
loc_regist_notna.head(3)
# Out:
#                                               user_id  \
# 43  d0903036489a613b93c0e7037227ea8784c3605cf9a3d4...
# 45  40c77d899a2e3d450ddfa0b992cf9ec08899ae838fa278...
# 69  321cfe8c4510fb3fc9b9c4be89d0ca56a797308dff53c3...
#
#                                              event_id  \
# 43  6629d5a73302852ef915dbda22fa1994213eb36e41c893...
# 45  698c42fe0a65f35b77acbc485109e982eb4f72e313f29d...
# 69  6629d5a73302852ef915dbda22fa1994213eb36e41c893...
#
#                                       organization_id     transaction_date  \
# 43  9bace67f3bda20854668f8b8a6756d2541c6ec49223803...  2019-01-01 13:30:03
# 45  d560043d425e34bd6b17fea670e7d087f293404fc370a4...  2019-01-01 17:19:47
# 69  9bace67f3bda20854668f8b8a6756d2541c6ec49223803...  2019-01-02 08:46:07
#
#    event_type organization_type  \
# 43      Event   Event Organizer
# 45      Event   Event Organizer
# 69      Event   Event Organizer
#
#                                        event_category   user_type  \
# 43  Art Exhibition - Family - Art - Exhibition - G...  Registered
# 45        Seminar - Workshop - Networking - Education  Registered
# 69  Art Exhibition - Family - Art - Exhibition - G...  Registered
#
#    user_location event_location  gender  age_when_register  price  \
# 43       Jakarta        Jakarta  female               28.0  50000
# 45         Medan        Jakarta  female               19.0      0
# 69       Jakarta        Jakarta  female               26.0  50000
#
#     total_ticket_sold
# 43                  2
# 45                  1
# 69                  4

# %%
regist_not_web_notna = loc_regist_notna[(~loc_regist_notna['event_category'].str.contains('Webinar')==True) & (loc_regist_notna['event_location'] != 'Indonesia')]

# %%
regist_not_web_notna.groupby('user_location')['event_id'].value_counts()
# Out:
# user_location  event_id
# Bali           e6771360e4d6834825c98aaf0b31b7417ae00b89e4e13dd6f17a9f5bdfb37032    9
#                09cd82981be844fbd7b3fd9eba0bf48f569531a77a2601963c4e634878a87669    6
#                1f9dadc037de809cf2ecebab04fa3533aadf7476bb99e5c7e6592e4d8ea4624c    5
#                14ab144da2643b8a484f07971151f0cf501ba12e69daaae5e129bc81ae3bf4c9    4
#                6bacbebd8d909ba3dfb1a47bf8d272ad1a083701d625ccc2f20bc365de2857e4    4
#                                                                                   ..
# Yogyakarta     953e8635cc23864639d0530fa19639bd6250dcb47f363f6c0c604fbf686e0f71    1
#                9f51168136fa5fbef34f00b364328d9d6b393589fde86616d489d95e1cfcc2df    1
#                a2ca1b9ecb351b1dd4891c02d8e2958ac2e839cb7893fe134dd08cf5ae9a2b92    1
#                d703662dac6a3f47d6789be421c14222e24e44c7034aed83865955fbab694889    1
#                f1be90db3a6d7abb3b58491e482836dde80fcb1d7e8f892f467d0570ce461151    1
# Name: event_id, Length: 783, dtype: int64

# %%
regist_not_web_notna.groupby('event_id')['user_location'].unique().value_counts().head(10)
# Out:
# [Jakarta]                                                 179
# [Makassar]                                                 38
# [Bandung]                                                  29
# [Yogyakarta]                                               11
# [Tangerang]                                                10
# [Bekasi]                                                    8
# [Depok]                                                     5
# [Surabaya]                                                  5
# [Lampung]                                                   3
# [Jakarta, Semarang, Bandung, Bekasi, Tangerang, Depok]      1
# Name: user_location, dtype: int64

# %%
# Identify location

loc_jkt = regist_not_web_notna[regist_not_web_notna['user_location']=='Jakarta']['event_id'].tolist()
loc_mks = regist_not_web_notna[regist_not_web_notna['user_location']=='Makassar']['event_id'].tolist()
loc_bdg = regist_not_web_notna[regist_not_web_notna['user_location']=='Bandung']['event_id'].tolist()

# %%
# Jakarta

fill_jkt = loc_regist_isna[loc_regist_isna['event_id'].isin(loc_jkt)]
fill_jkt['user_location'] = fill_jkt['user_location'].fillna('Jakarta')

# %%
# Makassar

fill_mks = loc_regist_isna[loc_regist_isna['event_id'].isin(loc_mks)]
fill_mks['user_location'] = fill_mks['user_location'].fillna('Makassar')

# %%
# Bandung

fill_bdg = loc_regist_isna[loc_regist_isna['event_id'].isin(loc_bdg)]
fill_bdg['user_location'] = fill_bdg['user_location'].fillna('Bandung')

# %%
loc_regist_isna.fillna(fill_jkt, inplace=True)
loc_regist_isna.fillna(fill_mks, inplace=True)
loc_regist_isna.fillna(fill_bdg, inplace=True)

# %%
loc_regist_isna.isna().sum()
# Out:
# user_id                 0
# event_id                0
# organization_id         0
# transaction_date        0
# event_type              0
# organization_type       0
# event_category          0
# user_type               0
# user_location        4198
# event_location          0
# gender                101
# age_when_register     742
# price                   0
# total_ticket_sold       0
# dtype: int64

# %%
loc_guest_filled = pd.concat([loc_guest_isna, loc_guest_notna])
loc_regist_filled = pd.concat([loc_regist_isna, loc_regist_notna])
loc_filled = pd.concat([loc_guest_filled, loc_regist_filled])

# %%
# Merging to original dataframe

df.fillna(loc_filled, inplace=True)

# %%
df.isna().sum()
# Out:
# user_id                  0
# event_id                 0
# organization_id          0
# transaction_date         0
# event_type               0
# organization_type        0
# event_category           0
# user_type                0
# user_location        17192
# event_location           6
# gender                3827
# age_when_register    31804
# price                    0
# total_ticket_sold        0
# dtype: int64

# %% [markdown]
# > We move to **event location** and **gender** feature.

# %%
df[df['event_location'].isna()].groupby('user_type')['event_category'].value_counts()
# Out:
# user_type   event_category
# Guest       Online Event - Webinar    2
#             Festival - Music          1
# Registered  Online Event - Webinar    3
# Name: event_category, dtype: int64

# %% [markdown]
# > Seems that in this feature the online events and the guest type are causing the data to be missing. The one with **'Webinar'** category, we can fill it with **Indonesia**.

# %%
df[df['event_location'].isna()].groupby('user_type')['event_id'].value_counts()
# Out:
# user_type   event_id
# Guest       a51ab54c9c7394a052dc73b3adc164af628dcb1049e75912ecfb702b1024cd9a    2
#             83cadc8cf1544e253e3e75fdf140d38badbc1461124e4b75f6022d97747e8672    1
# Registered  a51ab54c9c7394a052dc73b3adc164af628dcb1049e75912ecfb702b1024cd9a    3
# Name: event_id, dtype: int64

# %%
df[df['event_id'] == '83cadc8cf1544e253e3e75fdf140d38badbc1461124e4b75f6022d97747e8672']
# Out:
#                                                  user_id  \
# 21800  20f1f78d5eb02b09a503b26e7294399b6b7b3ca7d1565f...
#
#                                                 event_id  \
# 21800  83cadc8cf1544e253e3e75fdf140d38badbc1461124e4b...
#
#                                          organization_id     transaction_date  \
# 21800  bf98663c9884ad409695575399cd63a9caf2217c742ae7...  2020-02-15 06:08:50
#
#       event_type             organization_type    event_category user_type  \
# 21800      Event  Event Organizer and Promotor  Festival - Music     Guest
#
#       user_location event_location gender  age_when_register    price  \
# 21800           NaN            NaN   none                NaN  3750000
#
#        total_ticket_sold
# 21800                  1

# %% [markdown]
# > Interestingly, this event are the only events that are avaliable, and the price are also quite expensive. But I think this might be a reasonable price, if we see the categories. Therefore let's try to explore further, maybe I'll narrow it down to typical concert ticket price range.

# %%
df[(df['price']>=2000000) & (df['price']<4000000)]['event_category'].value_counts()
# Out:
# Networking - Conference                                     353
# Conference                                                   25
# Festival - Music                                              8
# Seminar                                                       4
# Workshop - Seminar - Exibition - Networking - Conference      1
# Workshop - Travel - Seminar - Conference                      1
# Name: event_category, dtype: int64

# %% [markdown]
# > By doing this method, we found that there are 8 similar **Festival - Music** categories. And 7 of them are placed in **Jakarta**. Therefore, we'll fill out this missing values as **Jakarta**.

# %%
df[(df['price']>=2000000) & (df['price']<4000000) & (df['event_category']=='Festival - Music')]
# Out:
#                                                  user_id  \
# 14209  29b6e82d15f0f2916603012e411fc051ffd5f846743e87...
# 14210  6ad74168b85bad3c51762d130a3b3717bef7e969822863...
# 14370  7f2e9b1590a2f0dd4632ea3f5eebae5fa393c866de12c3...
# 14420  e5a5c2b89a0ea5691fb41cce94cdade05865969a9b32f1...
# 18029  ef44cb258a8e237518afc2d97e6912d4a0720e24c1f377...
# 21800  20f1f78d5eb02b09a503b26e7294399b6b7b3ca7d1565f...
# 39311  3b525e5bd4143c0609e7385869dcecd16f1dd39590347d...
# 39385  871d9a4d6c9c4b21caeb18c52d8b64c588e67e19af8f6f...
#
#                                                 event_id  \
# 14209  066fd583bb78d0125199ab4a8b5e4efb2953f0a24e2a39...
# 14210  066fd583bb78d0125199ab4a8b5e4efb2953f0a24e2a39...
# 14370  066fd583bb78d0125199ab4a8b5e4efb2953f0a24e2a39...
# 14420  066fd583bb78d0125199ab4a8b5e4efb2953f0a24e2a39...
# 18029  066fd583bb78d0125199ab4a8b5e4efb2953f0a24e2a39...
# 21800  83cadc8cf1544e253e3e75fdf140d38badbc1461124e4b...
# 39311  066fd583bb78d0125199ab4a8b5e4efb2953f0a24e2a39...
# 39385  066fd583bb78d0125199ab4a8b5e4efb2953f0a24e2a39...
#
#                                          organization_id     transaction_date  \
# 14209  bf98663c9884ad409695575399cd63a9caf2217c742ae7...  2019-09-20 17:20:03
# 14210  bf98663c9884ad409695575399cd63a9caf2217c742ae7...  2019-09-20 19:16:09
# 14370  bf98663c9884ad409695575399cd63a9caf2217c742ae7...  2019-09-24 07:58:23
# 14420  bf98663c9884ad409695575399cd63a9caf2217c742ae7...  2019-09-25 05:30:18
# 18029  bf98663c9884ad409695575399cd63a9caf2217c742ae7...  2019-11-13 14:55:37
# 21800  bf98663c9884ad409695575399cd63a9caf2217c742ae7...  2020-02-15 06:08:50
# 39311  bf98663c9884ad409695575399cd63a9caf2217c742ae7...  2019-09-24 17:49:46
# 39385  bf98663c9884ad409695575399cd63a9caf2217c742ae7...  2019-09-26 03:53:06
#
#       event_type             organization_type    event_category user_type  \
# 14209      Event  Event Organizer and Promotor  Festival - Music     Guest
# 14210      Event  Event Organizer and Promotor  Festival - Music     Guest
# 14370      Event  Event Organizer and Promotor  Festival - Music     Guest
# 14420      Event  Event Organizer and Promotor  Festival - Music     Guest
# 18029      Event  Event Organizer and Promotor  Festival - Music     Guest
# 21800      Event  Event Organizer and Promotor  Festival - Music     Guest
# 39311      Event  Event Organizer and Promotor  Festival - Music     Guest
# 39385      Event  Event Organizer and Promotor  Festival - Music     Guest
#
#       user_location event_location gender  age_when_register    price  \
# 14209       Jakarta        Jakarta   none                NaN  2100000
# 14210       Jakarta        Jakarta   none                NaN  2100000
# 14370       Jakarta        Jakarta   none                NaN  2100000
# 14420       Jakarta        Jakarta   none                NaN  2100000
# 18029       Jakarta        Jakarta   none                NaN  2100000
# 21800           NaN            NaN   none                NaN  3750000
# 39311       Jakarta        Jakarta   none                NaN  2100000
# 39385       Jakarta        Jakarta   none                NaN  2100000
#
#        total_ticket_sold
# 14209                  2
# 14210                  4
# 14370                  4
# 14420                  4
# 18029                  1
# 21800                  1
# 39311                  1
# 39385                  4

# %%
# Fill the null values

df[(df['price']>=2000000) & (df['price']<4000000) & (df['event_category']=='Festival - Music')].fillna(method = 'ffill', inplace=True)

# %%
# Merging to original dataframe

df['event_location'] = df['event_location'].fillna('Indonesia')

# %%
df.isna().sum()
# Out:
# user_id                  0
# event_id                 0
# organization_id          0
# transaction_date         0
# event_type               0
# organization_type        0
# event_category           0
# user_type                0
# user_location        17192
# event_location           0
# gender                3827
# age_when_register    31804
# price                    0
# total_ticket_sold        0
# dtype: int64

# %% [markdown]
# > Now that's cleared up. We're going to move to **gender** feature.

# %%
df[df['gender'].isna()].groupby('user_type')['event_category'].value_counts()
# Out:
# user_type   event_category
# Guest       Webinar - Concert - Education                                                          3462
#             Group Activities                                                                        160
#             Webinar                                                                                  49
#             Webinar - Game                                                                           13
#             Music - Concert                                                                           7
#             Music - Performance - Highschool Student - Pensi                                          4
#             Workshop                                                                                  4
#             Webinar - Tech Startup                                                                    3
#             Nightlife - Music                                                                         2
#             Seminar                                                                                   2
#             Webinar - Conference - Education - Networking - Seminar                                   2
#             Webinar - Education - Networking - Seminar                                                2
#             Art                                                                                       1
#             Movie Screening                                                                           1
#             Music - Festival - Concert                                                                1
#             Music - Food - Fashion - Festival                                                         1
#             Seminar - Art - Culture - Conference - Networking - Education                             1
#             Seminar - Tech Startup                                                                    1
#             Seminar - Workshop - Networking - Education                                               1
#             Travel - Group Activities - Water Park                                                    1
#             Webinar - Conference - Education - Education Expo - Networking - Seminar - Workshop       1
#             Webinar - Education                                                                       1
#             Webinar - Networking - Seminar                                                            1
#             Webinar - Seminar                                                                         1
#             Workshop - Seminar - Education - Networking                                               1
#             Workshop - Seminar - Talkshow - Career Expo - Conference                                  1
# Registered  Music - Concert                                                                          38
#             Webinar                                                                                  18
#             Webinar - Concert - Education                                                            17
#             Webinar - Tech Startup                                                                   10
#             Online Event - Webinar                                                                    4
#             Seminar - Art - Culture - Conference - Networking - Education                             2
#             Workshop - Seminar - Tech Startup                                                         2
#             Competition                                                                               1
#             Online Event - Conference - Talkshow - Workshop - Tech Startup - Education                1
#             Online Event - Game                                                                       1
#             Seminar - Education - Conference                                                          1
#             Travel - Group Activities - Water Park                                                    1
#             Webinar - Conference                                                                      1
#             Webinar - Conference - Education - Networking - Seminar                                   1
#             Webinar - Conference - Education - Networking - Seminar - Talkshow - Workshop             1
#             Webinar - Conference - Education - Networking - Seminar - Workshop                        1
#             Webinar - Education - Tech Startup                                                        1
#             Webinar - Game                                                                            1
#             Workshop                                                                                  1
# Name: event_category, dtype: int64

# %%
df[df['gender'].notna()].groupby('user_type')['event_category'].value_counts()
# Out:
# user_type   event_category
# Guest       Webinar                                                      3736
#             Workshop                                                     2183
#             Webinar - Tech Startup                                       1879
#             Talkshow                                                     1241
#             Seminar                                                      1165
#                                                                          ...
# Registered  Workshop - Seminar - Talkshow - Education - Networking          1
#             Workshop - Seminar - Talkshow - Networking - Conference         1
#             Workshop - Seminar - Talkshow - Tech Startup - Networking       1
#             Workshop - Seminar - Tech StArtup                               1
#             Workshop - Webinar - Online Event                               1
# Name: event_category, Length: 503, dtype: int64

# %%
df[df['gender'].notna()].groupby('event_category')['gender'].value_counts()
# Out:
# event_category                                                                                                  gender
# Art                                                                                                             male        1
# Art Exhibition - Family - Art - Exhibition - Group Activities - Museum - Photography - Art Space - Go to Malls  female    979
#                                                                                                                 none      776
#                                                                                                                 male       44
# Bazaar - Music - Culture - Festival - University Student - Competition                                          none        2
#                                                                                                                          ...
# Workshop - Webinar - Education                                                                                  male        8
#                                                                                                                 female      2
#                                                                                                                 none        1
# Workshop - Webinar - Online Event                                                                               female      2
#                                                                                                                 none        1
# Name: gender, Length: 660, dtype: int64

# %%
df[df['gender'].notna()].groupby('user_type')['gender'].value_counts()
# Out:
# user_type   gender
# Guest       none      23026
#             male       2165
#             female     1992
# Registered  female    14580
#             male       7600
#             none        842
# Name: gender, dtype: int64

# %%
# Fill guest user gender

gender_guest = df[(df['gender'].isna()) & (df['user_type']=='Guest')]

# Fill registered user gender

gender_regist = df[(df['gender'].isna()) & (df['user_type']!='Guest')]

# %%
gender_guest['gender'] = gender_guest['gender'].fillna('none')
gender_regist['gender'] = gender_regist['gender'].fillna('female')

# %%
gender_fills = pd.concat([gender_guest, gender_regist])

# %%
# Merging to original dataframe

df['gender'] = df['gender'].fillna(gender_fills['gender'])

# %%
df.isna().sum()
# Out:
# user_id                  0
# event_id                 0
# organization_id          0
# transaction_date         0
# event_type               0
# organization_type        0
# event_category           0
# user_type                0
# user_location        17192
# event_location           0
# gender                   0
# age_when_register    31804
# price                    0
# total_ticket_sold        0
# dtype: int64

# %% [markdown]
# > Now we go to next feature **age when register**. We will implement the same method as before.

# %%
df[df['age_when_register'].isna()]['user_type'].value_counts()
# Out:
# Guest         30894
# Registered      910
# Name: user_type, dtype: int64

# %%
df[df['age_when_register'].notna()]['user_type'].value_counts()
# Out:
# Registered    22215
# Guest            13
# Name: user_type, dtype: int64

# %% [markdown]
# > From above information, we can see that the missing values in this category are dominated by the **Guest** users. There are only 13 values filled and more than 30000 users are leaving this feature blanks. We will try to explore and mitigate this below.

# %%
df[(df['user_type']=='Registered') & (df['event_location'] != 'Indonesia')].groupby('age_when_register')['event_category'].value_counts()
# Out:
# age_when_register  event_category
# 0.0                Webinar                                                           2
#                    Online Event - Webinar - Tech Startup                             1
#                    Seminar - University Student - Networking                         1
# 9.0                Music - Food - Fashion - Festival                                13
#                    Travel - Group Activities - Water Park                           11
#                                                                                     ..
# 89.0               Music - Food - Fashion - Festival                                 1
#                    Seminar - Tech Startup                                            1
# 90.0               Seminar - Art - Culture - Conference - Networking - Education     1
#                    Seminar - Tech Startup                                            1
# 120.0              Music - Concert                                                   1
# Name: event_category, Length: 1729, dtype: int64

# %% [markdown]
# > Seeing above data, it seems a little bit odd since there are user with 0 age, and user with 89 to 120 age. I'll try to explore it below.

# %%
df['age_when_register'].value_counts().head(20)
# Out:
# 29.0    3386
# 17.0    3267
# 19.0    2198
# 18.0    1562
# 20.0    1094
# 21.0    1057
# 22.0     936
# 24.0     920
# 49.0     913
# 27.0     809
# 23.0     750
# 25.0     704
# 26.0     645
# 28.0     627
# 16.0     596
# 14.0     492
# 30.0     242
# 15.0     229
# 32.0     202
# 31.0     182
# Name: age_when_register, dtype: int64

# %%
df['age_when_register'].value_counts(ascending=True).head(20)
# Out:
# 63.0      1
# 3.0       1
# 61.0      1
# 56.0      1
# 58.0      1
# 72.0      1
# 120.0     1
# 57.0      2
# 90.0      2
# 55.0      2
# 54.0      3
# 62.0      3
# 59.0      3
# 11.0      4
# 89.0      5
# 0.0       6
# 52.0      8
# 45.0     15
# 53.0     16
# 10.0     16
# Name: age_when_register, dtype: int64

# %%
df['age_when_register'].sort_values(ascending=False).head(15)
# Out:
# 8502     120.0
# 5882      90.0
# 18555     90.0
# 915       89.0
# 37464     89.0
# 2033      89.0
# 1198      89.0
# 41450     89.0
# 30296     72.0
# 43301     63.0
# 51646     62.0
# 53303     62.0
# 21906     62.0
# 33166     61.0
# 12164     59.0
# Name: age_when_register, dtype: float64

# %%
df['age_when_register'].sort_values(ascending=True).head(15)
# Out:
# 23136    0.0
# 31331    0.0
# 24931    0.0
# 33261    0.0
# 31330    0.0
# 31327    0.0
# 52998    3.0
# 33260    9.0
# 37748    9.0
# 37680    9.0
# 38546    9.0
# 37678    9.0
# 11446    9.0
# 12183    9.0
# 20309    9.0
# Name: age_when_register, dtype: float64

# %%
df[df['age_when_register']>65]
# Out:
#                                                  user_id  \
# 915    b2fb2c1d094c9fcdd279474b12170d648b70eeecc6fb87...
# 1198   b2fb2c1d094c9fcdd279474b12170d648b70eeecc6fb87...
# 2033   b2fb2c1d094c9fcdd279474b12170d648b70eeecc6fb87...
# 5882   2a216ca0f56f5d5e8d17586efc24b3dee1073c4d3ad8c9...
# 8502   8c71a58e0bf9f82be88b17929c63384ba32b58a6be7a84...
# 18555  05c8dc87d4c865d05646617bfc4f0c42c4bb51ca5923a4...
# 30296  34bf65b3b0f5ab834f8961cf148a66d6d97cde49fd8804...
# 37464  ddc23e9940f3894dae65cb130b90a0a15efc59b0f2899d...
# 41450  6577762c90899409835d111cee022d0df2fdc0187db325...
#
#                                                 event_id  \
# 915    f4393b4283998e6d191a75984dc889277f0b245b673e5e...
# 1198   c4b31210e5fecaffc236fee3a858e92a395e2a79b0866c...
# 2033   c4b31210e5fecaffc236fee3a858e92a395e2a79b0866c...
# 5882   b5376c5e81bdd49acab2233e50d3fe4907332e72e8e5be...
# 8502   b5bfc041db54a1f27c6f6563f1b42706e994b4b8f6e82d...
# 18555  8a8c40cba849b7f31635583539dbc80fc7469592387bfc...
# 30296  552dcd9035c4d520da6318e41c831953b3f84c4a7a9cfc...
# 37464  9f51168136fa5fbef34f00b364328d9d6b393589fde866...
# 41450  8a8c40cba849b7f31635583539dbc80fc7469592387bfc...
#
#                                          organization_id     transaction_date  \
# 915    82ae7d8f032587ee2cd1f43ef733b1176d02aa13dc7132...  2019-01-21 14:41:38
# 1198   82ae7d8f032587ee2cd1f43ef733b1176d02aa13dc7132...  2019-02-18 08:23:33
# 2033   82ae7d8f032587ee2cd1f43ef733b1176d02aa13dc7132...  2019-02-19 10:37:24
# 5882   181f3c6fb709aceefd52c408ed503d9f970211a11d8c61...  2019-07-28 09:54:32
# 8502   db5b1e7d8aabff82a502dfdac3f701cd5daed066c65766...  2019-08-25 23:09:25
# 18555  dfc7c637af4a6e92c6a22e4dabed4f17b7a4be8ea8d567...  2019-12-04 14:03:27
# 30296  39d13f95b71eb21f7b80bb1fcc3795548688fd1a8e8f27...  2020-06-12 06:42:14
# 37464  00426f657147432f752353af9b2db7f19b52beefb261f6...  2019-09-02 13:03:52
# 41450  dfc7c637af4a6e92c6a22e4dabed4f17b7a4be8ea8d567...  2019-12-04 10:18:22
#
#       event_type             organization_type  \
# 915        Event               Event Organizer
# 1198       Event               Event Organizer
# 2033       Event               Event Organizer
# 5882       Event  Event Organizer and Promotor
# 8502       Event  Event Organizer and Promotor
# 18555      Event               Event Organizer
# 30296      Event  Event Organizer and Promotor
# 37464      Event               Event Organizer
# 41450      Event               Event Organizer
#
#                                           event_category   user_type  \
# 915                                             Workshop  Registered
# 1198                                            Workshop  Registered
# 2033                                            Workshop  Registered
# 5882   Seminar - Art - Culture - Conference - Network...  Registered
# 8502                                     Music - Concert  Registered
# 18555                             Seminar - Tech Startup  Registered
# 30296                                Webinar - Education  Registered
# 37464                  Music - Food - Fashion - Festival  Registered
# 41450                             Seminar - Tech Startup  Registered
#
#       user_location event_location  gender  age_when_register   price  \
# 915         Jakarta        Jakarta  female               89.0   50000
# 1198        Jakarta        Jakarta  female               89.0   50000
# 2033        Jakarta        Jakarta  female               89.0   50000
# 5882      Tangerang        Jakarta    male               90.0  419000
# 8502        Jakarta        Jakarta  female              120.0       0
# 18555       Bandung        Bandung    male               90.0       0
# 30296           NaN      Indonesia    male               72.0       0
# 37464     Tangerang      Tangerang  female               89.0   25000
# 41450       Bandung        Bandung    male               89.0       0
#
#        total_ticket_sold
# 915                    3
# 1198                   1
# 2033                   1
# 5882                   1
# 8502                   1
# 18555                  1
# 30296                  1
# 37464                  1
# 41450                  1

# %%
len(df)
# Out:
# 54032

# %%
# Drop value higher than 65 years

df = df.drop(df[df['age_when_register']>65].index)

# %%
len(df)
# Out:
# 54023

# %%
df[df['age_when_register']<18]
# Out:
#                                                  user_id  \
# 122    973254b7d9f271787318df5dffd2cbb39137570517f8e5...
# 286    01ec7f5c6166ecce5e79c05cc64b21e56a743d5543af8f...
# 287    01ec7f5c6166ecce5e79c05cc64b21e56a743d5543af8f...
# 438    fa85b7e099050ee35665fcd45d7dc1a802ce7379e3a9e8...
# 488    2daae7d143097267afb41fbdb9f5779f8091c4dab45e2c...
# ...                                                  ...
# 53837  bb447d8f7fa559afd5832227ffedf31a1641321d15073a...
# 53838  bb447d8f7fa559afd5832227ffedf31a1641321d15073a...
# 53839  bb447d8f7fa559afd5832227ffedf31a1641321d15073a...
# 53963  d2dd6035c1f5df9ff9af2cae002cf3e1f79cb0cafed659...
# 54009  5e2bf636f72d8c8848b99049c75ba4e6ac233d7a0ac9cc...
#
#                                                 event_id  \
# 122    6629d5a73302852ef915dbda22fa1994213eb36e41c893...
# 286    42fbc58b0793f7a78da3aed5023efa91bdfbf219963614...
# 287    42fbc58b0793f7a78da3aed5023efa91bdfbf219963614...
# 438    6283d5326523497874fd69beb5f4482054c44a08a0b28b...
# 488    42fbc58b0793f7a78da3aed5023efa91bdfbf219963614...
# ...                                                  ...
# 53837  215cc964404a1c632341a439e448bd5f1fd4db8ef781bf...
# 53838  215cc964404a1c632341a439e448bd5f1fd4db8ef781bf...
# 53839  215cc964404a1c632341a439e448bd5f1fd4db8ef781bf...
# 53963  0af23f9ed047e4068cfe24d0e75a7b5f641a9ae1ba0958...
# 54009  98a5e21b6cdcaa5e7d83bdb710b437afdb98904c79a899...
#
#                                          organization_id     transaction_date  \
# 122    9bace67f3bda20854668f8b8a6756d2541c6ec49223803...  2019-01-04 06:06:05
# 286    58b192b21f26e839d98afc2dce1e03e354756c73ed3f57...  2019-01-07 07:40:20
# 287    58b192b21f26e839d98afc2dce1e03e354756c73ed3f57...  2019-01-07 07:43:31
# 438    88b11b0e7ba1e23b5af6878605cc5afb77b4d36c88db7a...  2019-01-10 11:40:59
# 488    58b192b21f26e839d98afc2dce1e03e354756c73ed3f57...  2019-01-11 06:46:38
# ...                                                  ...                  ...
# 53837  edcd25f0614671feef2c5546910ce05a85396907974305...  2020-06-26 09:36:06
# 53838  edcd25f0614671feef2c5546910ce05a85396907974305...  2020-06-26 09:36:29
# 53839  edcd25f0614671feef2c5546910ce05a85396907974305...  2020-06-26 09:36:53
# 53963  c049c2410454768bc6f63910b4234ab909017bd06eea24...  2020-06-29 08:57:48
# 54009  307d540ca5f39eeeb489168598da8625d45ab0fa8fb14a...  2020-06-30 04:21:54
#
#       event_type             organization_type  \
# 122        Event               Event Organizer
# 286        Event               Event Organizer
# 287        Event               Event Organizer
# 438        Event  Event Organizer and Promotor
# 488        Event               Event Organizer
# ...          ...                           ...
# 53837      Event  Event Organizer and Promotor
# 53838      Event  Event Organizer and Promotor
# 53839      Event  Event Organizer and Promotor
# 53963      Event                Event Promotor
# 54009      Event  Event Organizer and Promotor
#
#                                           event_category   user_type  \
# 122    Art Exhibition - Family - Art - Exhibition - G...  Registered
# 286                            Wedding Expo - Exhibition  Registered
# 287                            Wedding Expo - Exhibition  Registered
# 438                         University Student - Seminar  Registered
# 488                            Wedding Expo - Exhibition  Registered
# ...                                                  ...         ...
# 53837                                            Webinar  Registered
# 53838                                            Webinar  Registered
# 53839                                            Webinar  Registered
# 53963                                            Webinar  Registered
# 54009                                     Webinar - Game  Registered
#
#       user_location event_location  gender  age_when_register   price  \
# 122         Jakarta        Jakarta  female                9.0   50000
# 286         Jakarta        Jakarta  female               16.0   15000
# 287         Jakarta        Jakarta  female               16.0   15000
# 438      Yogyakarta        Bandung    male               16.0  150000
# 488         Jakarta        Jakarta    male               13.0   15000
# ...             ...            ...     ...                ...     ...
# 53837       Jakarta      Indonesia  female               17.0       0
# 53838       Jakarta      Indonesia  female               17.0       0
# 53839       Jakarta      Indonesia  female               17.0       0
# 53963           NaN        Jakarta  female               17.0       0
# 54009           NaN      Indonesia    male               17.0       0
#
#        total_ticket_sold
# 122                    3
# 286                    1
# 287                    1
# 438                    1
# 488                    2
# ...                  ...
# 53837                  1
# 53838                  1
# 53839                  1
# 53963                  1
# 54009                  1
#
# [4842 rows x 14 columns]

# %%
# Fill value lower than 18 to 18 based on TOC

df.loc[df['age_when_register']<18, 'age_when_register']=18

# %%
df[df['age_when_register']==18]
# Out:
#                                                  user_id  \
# 120    65bc210110ba137cd2a36c03104b2b1bbcdd286071da7a...
# 122    973254b7d9f271787318df5dffd2cbb39137570517f8e5...
# 286    01ec7f5c6166ecce5e79c05cc64b21e56a743d5543af8f...
# 287    01ec7f5c6166ecce5e79c05cc64b21e56a743d5543af8f...
# 390    a220b54c23a892a78ca07f2ff441ece11d0f2ca86c2ad6...
# ...                                                  ...
# 53982  24a966bb7fdd0e54529ad245776fd776e2469cf476f4c5...
# 53983  24a966bb7fdd0e54529ad245776fd776e2469cf476f4c5...
# 53984  24a966bb7fdd0e54529ad245776fd776e2469cf476f4c5...
# 53994  5bacb5c19594bc0a0bf19b1402d09e35e84c7736b77846...
# 54009  5e2bf636f72d8c8848b99049c75ba4e6ac233d7a0ac9cc...
#
#                                                 event_id  \
# 120    6629d5a73302852ef915dbda22fa1994213eb36e41c893...
# 122    6629d5a73302852ef915dbda22fa1994213eb36e41c893...
# 286    42fbc58b0793f7a78da3aed5023efa91bdfbf219963614...
# 287    42fbc58b0793f7a78da3aed5023efa91bdfbf219963614...
# 390    6629d5a73302852ef915dbda22fa1994213eb36e41c893...
# ...                                                  ...
# 53982  13b9749de18eafbbedc6d3e04071f1b0c02e454b91a11c...
# 53983  17a40b515b6a53a300ee81c87ccd3a35d33fdcc0bfa605...
# 53984  e8f3cb7ee3d9227a5300eb4546e1fded1c59cdd6801d64...
# 53994  d161f9f74fa109cc6642db193903181cc6031357e71999...
# 54009  98a5e21b6cdcaa5e7d83bdb710b437afdb98904c79a899...
#
#                                          organization_id     transaction_date  \
# 120    9bace67f3bda20854668f8b8a6756d2541c6ec49223803...  2019-01-04 05:42:16
# 122    9bace67f3bda20854668f8b8a6756d2541c6ec49223803...  2019-01-04 06:06:05
# 286    58b192b21f26e839d98afc2dce1e03e354756c73ed3f57...  2019-01-07 07:40:20
# 287    58b192b21f26e839d98afc2dce1e03e354756c73ed3f57...  2019-01-07 07:43:31
# 390    9bace67f3bda20854668f8b8a6756d2541c6ec49223803...  2019-01-09 17:07:04
# ...                                                  ...                  ...
# 53982  50540ee80dbc052ba69dbdfb8f61afc9b1cda2228d1926...  2020-06-29 12:06:54
# 53983  98ed8887cc16897a4dd73a422e2a0ae27c93f76269f0cc...  2020-06-29 12:07:26
# 53984  98ed8887cc16897a4dd73a422e2a0ae27c93f76269f0cc...  2020-06-29 12:07:56
# 53994  d8c53de2e0a2cab13623ddec1b968f3a88db68d8eceef7...  2020-06-29 14:21:34
# 54009  307d540ca5f39eeeb489168598da8625d45ab0fa8fb14a...  2020-06-30 04:21:54
#
#       event_type             organization_type  \
# 120        Event               Event Organizer
# 122        Event               Event Organizer
# 286        Event               Event Organizer
# 287        Event               Event Organizer
# 390        Event               Event Organizer
# ...          ...                           ...
# 53982      Event                     Community
# 53983      Event  Event Organizer and Promotor
# 53984      Event  Event Organizer and Promotor
# 53994      Event  Event Organizer and Promotor
# 54009      Event  Event Organizer and Promotor
#
#                                           event_category   user_type  \
# 120    Art Exhibition - Family - Art - Exhibition - G...  Registered
# 122    Art Exhibition - Family - Art - Exhibition - G...  Registered
# 286                            Wedding Expo - Exhibition  Registered
# 287                            Wedding Expo - Exhibition  Registered
# 390    Art Exhibition - Family - Art - Exhibition - G...  Registered
# ...                                                  ...         ...
# 53982                                            Webinar  Registered
# 53983           Webinar - Education - Networking - Sport  Registered
# 53984         Webinar - Education - Networking - Seminar  Registered
# 53994                                            Webinar  Registered
# 54009                                     Webinar - Game  Registered
#
#       user_location event_location  gender  age_when_register  price  \
# 120         Jakarta        Jakarta  female               18.0  50000
# 122         Jakarta        Jakarta  female               18.0  50000
# 286         Jakarta        Jakarta  female               18.0  15000
# 287         Jakarta        Jakarta  female               18.0  15000
# 390         Lampung        Jakarta  female               18.0  50000
# ...             ...            ...     ...                ...    ...
# 53982           NaN        Jakarta  female               18.0      0
# 53983           NaN        Bandung  female               18.0      0
# 53984           NaN        Jakarta  female               18.0      0
# 53994           NaN      Indonesia    male               18.0      0
# 54009           NaN      Indonesia    male               18.0      0
#
#        total_ticket_sold
# 120                    2
# 122                    3
# 286                    1
# 287                    1
# 390                    4
# ...                  ...
# 53982                  1
# 53983                  1
# 53984                  1
# 53994                  1
# 54009                  1
#
# [6404 rows x 14 columns]

# %%
df.groupby('event_id')['age_when_register'].value_counts()
# Out:
# event_id                                                          age_when_register
# 001a53ec299ccc475e255a8297c76a34a3ada44db051518ac05567cff904f4ff  25.0                 2
#                                                                   18.0                 1
#                                                                   19.0                 1
# 0076ded2b0908462ecf5753646cf20ab41b26b3ec9b144c39f90b40b941655a7  23.0                 2
#                                                                   26.0                 2
#                                                                                       ..
# ffbfd3c819ce1dc283e6ed6cb1a7172f6f4c7e45eba417cc9bb16528f60e9be5  31.0                 1
#                                                                   32.0                 1
#                                                                   35.0                 1
#                                                                   48.0                 1
#                                                                   49.0                 1
# Name: age_when_register, Length: 3835, dtype: int64

# %%
age_isna = df[df['age_when_register'].isna()]
age_notna = df[df['age_when_register'].notna()]

# %%
age_notna.groupby('event_id')['age_when_register'].value_counts().head(30)
# Out:
# event_id                                                          age_when_register
# 001a53ec299ccc475e255a8297c76a34a3ada44db051518ac05567cff904f4ff  25.0                 2
#                                                                   18.0                 1
#                                                                   19.0                 1
# 0076ded2b0908462ecf5753646cf20ab41b26b3ec9b144c39f90b40b941655a7  23.0                 2
#                                                                   26.0                 2
#                                                                   24.0                 1
#                                                                   27.0                 1
#                                                                   32.0                 1
# 015b8977189eb613d24ffaa9c53fbf9bcb42a31a005f5e11aea6e03eccc650a5  21.0                 1
#                                                                   39.0                 1
# 017859023da7d47af5353d9ddef29a377bc85785e7ddc89d26b57f455da5796b  29.0                 1
#                                                                   31.0                 1
# 0197c2cd604540c0e713eaf333e25348640c5a9b51237e369c4f0e3704c063e6  20.0                 1
#                                                                   21.0                 1
#                                                                   31.0                 1
# 032223202ad883165f8fe2e3940f247e771c0137378dfa7779b6689048d91867  27.0                 1
# 0371333c679220030a17dcee1679d7a03bc650e0c07575c3c78d42b1603f1bff  28.0                 2
# 03feb53811ccbeefd2ffc285e1ae2ea596c2c4222a3ad6ea4e94f833ce331c0e  20.0                 1
#                                                                   21.0                 1
#                                                                   23.0                 1
#                                                                   27.0                 1
#                                                                   34.0                 1
# 04005bd94a700a2c0c292cac351b67df11701b5109b90e5f163c92a5a6c89fa7  20.0                 1
#                                                                   22.0                 1
#                                                                   25.0                 1
#                                                                   28.0                 1
#                                                                   34.0                 1
#                                                                   44.0                 1
#                                                                   46.0                 1
# 04465e08244ba31c77ff0e2280d558b94438d32eed83e8696d3765b0bc2bb9c6  20.0                 7
# Name: age_when_register, dtype: int64

# %%
age_isna[age_isna['event_id'].isin(age_notna['event_id'])]
# Out:
#                                                  user_id  \
# 0      4f3e46a6e94452b566553485b619d2f305bd9d875d4f6d...
# 3      b1fc4cf5297d6639937d7806cf8ff626e4fdef6548c892...
# 4      1da4ae70dde95b9d83c7586d1af62599cb01c4fc660f63...
# 5      7dddb95cc3da557d3c0b993d4ad148182cdccd5833387e...
# 6      ebee53b4d8aa0e1d82385d191b9a6b27c21125689f99f7...
# ...                                                  ...
# 54025  2c44415066b2c29532d3a64ecb065bffc89474dc5ccb64...
# 54026  883e0a9bf3352ebb582b83db4e806702562ff243586f55...
# 54027  533449881c251c76163bcf060a0b6f5a086b563506d825...
# 54029  0c4a0bcdf8904e211ca9ef5ed3612f5239ff4ccf9fe21b...
# 54031  0011ca61ac7147b9dc6bd90b2531ba733cca1c2ad18e23...
#
#                                                 event_id  \
# 0      6629d5a73302852ef915dbda22fa1994213eb36e41c893...
# 3      6629d5a73302852ef915dbda22fa1994213eb36e41c893...
# 4      6629d5a73302852ef915dbda22fa1994213eb36e41c893...
# 5      6629d5a73302852ef915dbda22fa1994213eb36e41c893...
# 6      42fbc58b0793f7a78da3aed5023efa91bdfbf219963614...
# ...                                                  ...
# 54025  215cc964404a1c632341a439e448bd5f1fd4db8ef781bf...
# 54026  98a5e21b6cdcaa5e7d83bdb710b437afdb98904c79a899...
# 54027  215cc964404a1c632341a439e448bd5f1fd4db8ef781bf...
# 54029  091083ed26d4daa659a2b11d91dccc33d4048977ac0a62...
# 54031  215cc964404a1c632341a439e448bd5f1fd4db8ef781bf...
#
#                                          organization_id     transaction_date  \
# 0      9bace67f3bda20854668f8b8a6756d2541c6ec49223803...  2019-01-01 03:04:32
# 3      9bace67f3bda20854668f8b8a6756d2541c6ec49223803...  2019-01-01 03:24:59
# 4      9bace67f3bda20854668f8b8a6756d2541c6ec49223803...  2019-01-01 03:53:11
# 5      9bace67f3bda20854668f8b8a6756d2541c6ec49223803...  2019-01-01 05:12:57
# 6      58b192b21f26e839d98afc2dce1e03e354756c73ed3f57...  2019-01-01 05:13:45
# ...                                                  ...                  ...
# 54025  edcd25f0614671feef2c5546910ce05a85396907974305...  2020-06-30 10:16:43
# 54026  307d540ca5f39eeeb489168598da8625d45ab0fa8fb14a...  2020-06-30 12:51:51
# 54027  edcd25f0614671feef2c5546910ce05a85396907974305...  2020-06-30 13:06:28
# 54029  d54b1a5795940aeee05ad0d0232a74666ef1095ccec17a...  2020-06-30 16:15:58
# 54031  edcd25f0614671feef2c5546910ce05a85396907974305...  2020-06-30 22:54:41
#
#       event_type             organization_type  \
# 0          Event               Event Organizer
# 3          Event               Event Organizer
# 4          Event               Event Organizer
# 5          Event               Event Organizer
# 6          Event               Event Organizer
# ...          ...                           ...
# 54025      Event  Event Organizer and Promotor
# 54026      Event  Event Organizer and Promotor
# 54027      Event  Event Organizer and Promotor
# 54029      Event  Event Organizer and Promotor
# 54031      Event  Event Organizer and Promotor
#
#                                           event_category user_type  \
# 0      Art Exhibition - Family - Art - Exhibition - G...     Guest
# 3      Art Exhibition - Family - Art - Exhibition - G...     Guest
# 4      Art Exhibition - Family - Art - Exhibition - G...     Guest
# 5      Art Exhibition - Family - Art - Exhibition - G...     Guest
# 6                              Wedding Expo - Exhibition     Guest
# ...                                                  ...       ...
# 54025                                            Webinar     Guest
# 54026                                     Webinar - Game     Guest
# 54027                                            Webinar     Guest
# 54029                                            Webinar     Guest
# 54031                                            Webinar     Guest
#
#       user_location event_location gender  age_when_register  price  \
# 0           Jakarta        Jakarta   none                NaN  75000
# 3           Jakarta        Jakarta   none                NaN  75000
# 4           Jakarta        Jakarta   none                NaN  75000
# 5           Jakarta        Jakarta   none                NaN  75000
# 6           Jakarta        Jakarta   none                NaN  15000
# ...             ...            ...    ...                ...    ...
# 54025           NaN      Indonesia   none                NaN      0
# 54026           NaN      Indonesia   none                NaN      0
# 54027           NaN      Indonesia   none                NaN      0
# 54029           NaN      Indonesia   none                NaN  50000
# 54031           NaN      Indonesia   none                NaN      0
#
#        total_ticket_sold
# 0                      2
# 3                      6
# 4                      2
# 5                      4
# 6                      2
# ...                  ...
# 54025                  1
# 54026                  1
# 54027                  1
# 54029                  1
# 54031                  1
#
# [31501 rows x 14 columns]

# %%
age = age_notna[age_notna['event_id'].isin(age_isna['event_id'])]

# %%
age['event_id'].value_counts().head(10)
# Out:
# c7463ebc8675f70869a51f85bc9b3a54dcb403a46b6d979a6ac8d7f925a553ad    2675
# 9f51168136fa5fbef34f00b364328d9d6b393589fde86616d489d95e1cfcc2df    2354
# 209839b3830376c3d0d56cc229843236518737303ccabcdd9c0c2199f27e34df    1412
# 0823bec079e5e7449851c82b4583fefa40e2dcc75c49494c593f3b1bb19919eb    1071
# bbe4d5bcda2e9f0be5d73a917e00a660f62fb027cde81cde843101560789a00d    1044
# 6629d5a73302852ef915dbda22fa1994213eb36e41c893f4d9391f1e2215aee7    1010
# 7d23fdf40253bc8aab93fb807851daa96da6b1b02f6ea53fcf92e1991c5f76be     867
# 9441a919384943d46915a2efaaad637bb0ca08cf0de0d96a19597aa72ba8d6b2     431
# f0dc0a7123bedcec5464c2518e47491fa6baa9970850c70fa5067200d9d7284d     350
# b5376c5e81bdd49acab2233e50d3fe4907332e72e8e5bee67a7a059ad65a6ec7     345
# Name: event_id, dtype: int64

# %%
# Locating event_id

age_evnt1 = age_isna[age_isna['event_id'] == 'c7463ebc8675f70869a51f85bc9b3a54dcb403a46b6d979a6ac8d7f925a553ad']
age_evnt2 = age_isna[age_isna['event_id'] == '9f51168136fa5fbef34f00b364328d9d6b393589fde86616d489d95e1cfcc2df']
age_evnt3 = age_isna[age_isna['event_id'] == '209839b3830376c3d0d56cc229843236518737303ccabcdd9c0c2199f27e34df']
age_evnt4 = age_isna[age_isna['event_id'] == '0823bec079e5e7449851c82b4583fefa40e2dcc75c49494c593f3b1bb19919eb']
age_evnt5 = age_isna[age_isna['event_id'] == 'bbe4d5bcda2e9f0be5d73a917e00a660f62fb027cde81cde843101560789a00d']
age_evnt6 = age_isna[age_isna['event_id'] == '6629d5a73302852ef915dbda22fa1994213eb36e41c893f4d9391f1e2215aee7']

# %%
# Measure filled values

age_fill1 = round(age[age['event_id']=='c7463ebc8675f70869a51f85bc9b3a54dcb403a46b6d979a6ac8d7f925a553ad']['age_when_register'].mean())
age_fill2 = round(age[age['event_id']=='9f51168136fa5fbef34f00b364328d9d6b393589fde86616d489d95e1cfcc2df']['age_when_register'].mean())
age_fill3 = round(age[age['event_id']=='209839b3830376c3d0d56cc229843236518737303ccabcdd9c0c2199f27e34df']['age_when_register'].mean())
age_fill4 = round(age[age['event_id']=='0823bec079e5e7449851c82b4583fefa40e2dcc75c49494c593f3b1bb19919eb']['age_when_register'].mean())
age_fill5 = round(age[age['event_id']=='bbe4d5bcda2e9f0be5d73a917e00a660f62fb027cde81cde843101560789a00d']['age_when_register'].mean())
age_fill6 = round(age[age['event_id']=='6629d5a73302852ef915dbda22fa1994213eb36e41c893f4d9391f1e2215aee7']['age_when_register'].mean())

# %%
# Filling missing value

age_evnt1['age_when_register'] = age_evnt1['age_when_register'].fillna(age_fill1)
age_evnt2['age_when_register'] = age_evnt2['age_when_register'].fillna(age_fill2)
age_evnt3['age_when_register'] = age_evnt3['age_when_register'].fillna(age_fill3)
age_evnt4['age_when_register'] = age_evnt4['age_when_register'].fillna(age_fill4)
age_evnt5['age_when_register'] = age_evnt5['age_when_register'].fillna(age_fill5)
age_evnt6['age_when_register'] = age_evnt6['age_when_register'].fillna(age_fill6)

# %%
age_filled = pd.concat([age_evnt1, age_evnt2, age_evnt3, age_evnt4, age_evnt5, age_evnt6])

# %%
age_isna['age_when_register'] = age_isna['age_when_register'].fillna(age_filled['age_when_register'])

# %%
age_fill = pd.concat([age_isna, age_notna])

# %%
# Merging to original dataframe

df['age_when_register'] = df['age_when_register'].fillna(age_fill['age_when_register'])

# %%
df.isna().sum()
# Out:
# user_id                  0
# event_id                 0
# organization_id          0
# transaction_date         0
# event_type               0
# organization_type        0
# event_category           0
# user_type                0
# user_location        17191
# event_location           0
# gender                   0
# age_when_register    28876
# price                    0
# total_ticket_sold        0
# dtype: int64

# %%
df[df['age_when_register'].isna()]['user_type'].value_counts()
# Out:
# Guest         28037
# Registered      839
# Name: user_type, dtype: int64

# %%
df[df['age_when_register'].notna()]['user_type'].value_counts()
# Out:
# Registered    22277
# Guest          2870
# Name: user_type, dtype: int64

# %%
pd.DataFrame({'dataFeatures' : df.columns, 'dataType' : df.dtypes.values, 
              'null' : [df[i].isna().sum() for i in df.columns],
              'nullPct' : [((df[i].isna().sum()/len(df[i]))*100).round(1) for i in df.columns],
              'Nunique' : [df[i].nunique() for i in df.columns],
              'uniqueSample' : [list(pd.Series(df[i].unique()).sample()) for i in df.columns]}).reset_index(drop = True)
# Out:
#          dataFeatures dataType   null  nullPct  Nunique  \
# 0             user_id   object      0      0.0    32171
# 1            event_id   object      0      0.0      811
# 2     organization_id   object      0      0.0      274
# 3    transaction_date   object      0      0.0    49299
# 4          event_type   object      0      0.0        1
# 5   organization_type   object      0      0.0        7
# 6      event_category   object      0      0.0      296
# 7           user_type   object      0      0.0        2
# 8       user_location   object  17191     31.8       37
# 9      event_location   object      0      0.0       23
# 10             gender   object      0      0.0        3
# 11  age_when_register  float64  28876     53.5       45
# 12              price    int64      0      0.0      119
# 13  total_ticket_sold    int64      0      0.0       47
#
#                                          uniqueSample
# 0   [c74259c0557fd505c19b66142a29e5d5e610ee565eca3...
# 1   [07a2d00608bde67f29b56ece7ce7f129a19c5a1d6596b...
# 2   [9000a2da973b96eae18bba26566e768e5daf64fd228d8...
# 3                               [2019-03-08 07:21:51]
# 4                                             [Event]
# 5                                   [Event Organizer]
# 6                                [Travel - Adventure]
# 7                                             [Guest]
# 8                                        [Balikpapan]
# 9                                            [Madiun]
# 10                                             [none]
# 11                                             [43.0]
# 12                                            [65000]
# 13                                                [9]

# %% [markdown]
# > Now we will fix the other datatype.

# %%
df[df['user_type']=='Guest']['age_when_register'].median()
# Out:
# 21.0

# %%
# Fill the rest of missing values

df['user_location'] = df['user_location'].fillna('Unknown')
df['age_when_register'] = df['age_when_register'].fillna(21)

# %%
# transaction date

df['transaction_date'] = pd.to_datetime(df['transaction_date'])

# %%
# age when register

df['age_when_register'] = df['age_when_register'].astype('int64')

# %%
# price 

df['price'] = df['price'].astype(float)

# %%
pd.DataFrame({'dataFeatures' : df.columns, 'dataType' : df.dtypes.values, 
              'null' : [df[i].isna().sum() for i in df.columns],
              'nullPct' : [((df[i].isna().sum()/len(df[i]))*100).round(1) for i in df.columns],
              'Nunique' : [df[i].nunique() for i in df.columns],
              'uniqueSample' : [list(pd.Series(df[i].unique()).sample()) for i in df.columns]}).reset_index(drop = True)
# Out:
#          dataFeatures        dataType  null  nullPct  Nunique  \
# 0             user_id          object     0      0.0    32171
# 1            event_id          object     0      0.0      811
# 2     organization_id          object     0      0.0      274
# 3    transaction_date  datetime64[ns]     0      0.0    49299
# 4          event_type          object     0      0.0        1
# 5   organization_type          object     0      0.0        7
# 6      event_category          object     0      0.0      296
# 7           user_type          object     0      0.0        2
# 8       user_location          object     0      0.0       38
# 9      event_location          object     0      0.0       23
# 10             gender          object     0      0.0        3
# 11  age_when_register           int64     0      0.0       45
# 12              price         float64     0      0.0      119
# 13  total_ticket_sold           int64     0      0.0       47
#
#                                          uniqueSample
# 0   [18052f82ea9700978f93bf06b0eeb50613ac476d16609...
# 1   [bfb01498d470b4af8cf39f9ad81adec8df953b361c57f...
# 2   [1c0b8a0321e01fe2082f5cf29cbced800b5e7ba60e077...
# 3                               [2020-02-09 06:34:59]
# 4                                             [Event]
# 5                      [Event Organizer and Promotor]
# 6                    [Seminar - Education - Talkshow]
# 7                                             [Guest]
# 8                                          [Makassar]
# 9                                             [Medan]
# 10                                             [none]
# 11                                               [49]
# 12                                        [1320000.0]
# 13                                               [32]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54023 entries, 0 to 54031
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            54023 non-null  object
#  1   event_id           54023 non-null  object
#  2   organization_id    54023 non-null  object
#  3   transaction_date   54023 non-null  datetime64[ns]
#  4   event_type         54023 non-null  object
#  5   organization_type  54023 non-null  object
#  6   event_category     54023 non-null  object
#  7   user_type          54023 non-null  object
#  8   user_location      54023 non-null  object
#  9   event_location     54023 non-null  object
#  10  gender             54023 non-null  object
#  11  age_when_register  54023 non-null  int64
#  12  price              54023 non-null  float64
#  13  total_ticket_sold  54023 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(10)
# memory usage: 6.2+ MB

# %% [markdown]
# > Now that the data have been properly cleaned. I'll pass it into new dataframe to later use it for EDA.

# %%
# Pass cleaned data to new dataframe

df.to_csv('dataset\evnts_clean.csv', index=False)

# %%
df_new = pd.read_csv('dataset\evnts_clean.csv')

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54023 entries, 0 to 54022
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            54023 non-null  object
#  1   event_id           54023 non-null  object
#  2   organization_id    54023 non-null  object
#  3   transaction_date   54023 non-null  object
#  4   event_type         54023 non-null  object
#  5   organization_type  54023 non-null  object
#  6   event_category     54023 non-null  object
#  7   user_type          54023 non-null  object
#  8   user_location      54023 non-null  object
#  9   event_location     54023 non-null  object
#  10  gender             54023 non-null  object
#  11  age_when_register  54023 non-null  int64
#  12  price              54023 non-null  float64
#  13  total_ticket_sold  54023 non-null  int64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 5.8+ MB
