# %% [markdown]
# ## IMPORT LIBRARIES

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import re

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## OVERVIEW

# %%
df = pd.read_csv('dataset\movie.csv')

# %%
df.head(3)
# Out:
#                                              user_id  \
# 0  50bd7b56b494e843cf8cc86deba1746b5dcb3622871c3c...
# 1  5ab517007fc2fa2256ccb5179cf2f85fb6333c0b97e78f...
# 2  b9c12d8ea302adcf5c1583367702dfeff02c00bb3a247b...
#
#                                             event_id     transaction_date  \
# 0  3757175fd0193ff5f0610a51c0c66bc2f23a027c76b0f7...  2019-01-01 05:51:06
# 1  ce3ef49344353815e0e6bb9be1e94cae9e3dcf19e21931...  2019-01-03 06:24:18
# 2  b8e87ba403345ef34659cfce029a68f73ec6f89eee59e2...  2019-01-03 07:55:14
#
#   event_type organization_type     event_category   user_type user_location  \
# 0      Movie           Cinemas  Movies or Cinemas  Registered       Bandung
# 1      Movie           Cinemas  Movies or Cinemas  Registered         Depok
# 2      Movie           Cinemas  Movies or Cinemas  Registered       Jakarta
#
#    gender  age_when_register  price  total_ticket_sold
# 0  female               17.0  50000                  3
# 1  female               21.0  35000                  2
# 2    male               25.0  50000                  3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15138 entries, 0 to 15137
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            15138 non-null  object
#  1   event_id           15138 non-null  object
#  2   transaction_date   15138 non-null  object
#  3   event_type         15138 non-null  object
#  4   organization_type  15138 non-null  object
#  5   event_category     15138 non-null  object
#  6   user_type          15138 non-null  object
#  7   user_location      10457 non-null  object
#  8   gender             15115 non-null  object
#  9   age_when_register  12256 non-null  float64
#  10  price              15138 non-null  int64
#  11  total_ticket_sold  15138 non-null  int64
# dtypes: float64(1), int64(2), object(9)
# memory usage: 1.4+ MB

# %%
pd.DataFrame({'dataFeatures' : df.columns, 'dataType' : df.dtypes.values, 
              'null' : [df[i].isna().sum() for i in df.columns],
              'nullPct' : [((df[i].isna().sum()/len(df[i]))*100).round(1) for i in df.columns],
              'Nunique' : [df[i].nunique() for i in df.columns],
              'uniqueSample' : [list(pd.Series(df[i].unique()).sample()) for i in df.columns]}).reset_index(drop = True)
# Out:
#          dataFeatures dataType  null  nullPct  Nunique  \
# 0             user_id   object     0      0.0     5038
# 1            event_id   object     0      0.0     5289
# 2    transaction_date   object     0      0.0    14945
# 3          event_type   object     0      0.0        1
# 4   organization_type   object     0      0.0        1
# 5      event_category   object     0      0.0        1
# 6           user_type   object     0      0.0        2
# 7       user_location   object  4681     30.9       30
# 8              gender   object    23      0.2        3
# 9   age_when_register  float64  2882     19.0       60
# 10              price    int64     0      0.0       41
# 11  total_ticket_sold    int64     0      0.0        8
#
#                                          uniqueSample
# 0   [7a8aed27e48f168ae7dd929b4ba27d825f59ae53281be...
# 1   [349c441f5562531a58593751f2a613d76ae0c864d9448...
# 2                               [2019-02-27 06:46:47]
# 3                                             [Movie]
# 4                                           [Cinemas]
# 5                                 [Movies or Cinemas]
# 6                                             [Guest]
# 7                                           [Cirebon]
# 8                                               [nan]
# 9                                              [62.0]
# 10                                            [50000]
# 11                                                [6]

# %%
df.describe().T
# Out:
#                      count          mean           std     min      25%  \
# age_when_register  12256.0     27.548548     10.576091     9.0     21.0
# price              15138.0  40710.959176  14850.901880  5000.0  35000.0
# total_ticket_sold  15138.0      1.672678      0.947632     1.0      1.0
#
#                        50%      75%       max
# age_when_register     24.0     30.0      90.0
# price              35000.0  45000.0  500000.0
# total_ticket_sold      2.0      2.0       8.0

# %%
df.describe(include = 'object').T
# Out:
#                    count unique  \
# user_id            15138   5038
# event_id           15138   5289
# transaction_date   15138  14945
# event_type         15138      1
# organization_type  15138      1
# event_category     15138      1
# user_type          15138      2
# user_location      10457     30
# gender             15115      3
#
#                                                                  top   freq
# user_id            fd1d86e37e79a7f3412818a79f22a3fccb52ced852664e...    555
# event_id           c71952786040a4b56ac78f3bd22b8608e4b32da54b457f...    206
# transaction_date                                 2019-11-07 07:12:20      4
# event_type                                                     Movie  15138
# organization_type                                            Cinemas  15138
# event_category                                     Movies or Cinemas  15138
# user_type                                                 Registered  12306
# user_location                                             Yogyakarta   4205
# gender                                                        female   6576

# %% [markdown]
# ## PREPROCESSING

# %% [markdown]
# > Let's start from **user location**.

# %%
df[df['user_location'].isna()]
# Out:
#                                                  user_id  \
# 46     c43bc48c9bdb9f609879b41bf36ab18a51641620994b2c...
# 89     367b471b3e1707de4303ee0525a54d212f93a2177897a1...
# 94     97f0e8938bbfe3e6245fee82693ae69577545ac12c4f90...
# 98     ba87885bc2cce3afb0915f6d4bee29f3f7926ed03c75bf...
# 100    a0145331389e0662f4c99950648bad94da75583d354377...
# ...                                                  ...
# 15130  fc1bdbf6277f8fa7cac344973a0835efeb04dfca5a95c0...
# 15131  fc1bdbf6277f8fa7cac344973a0835efeb04dfca5a95c0...
# 15134  f020e02f914012b2642463c4f26500cf63f98fc7e92222...
# 15135  d0f508f59f2d9450cc503a0f93ba7e26c670636953a995...
# 15136  91e247a231c3f22194cd6834528a863d90d66bccdcc4a6...
#
#                                                 event_id     transaction_date  \
# 46     ecb2b8f3697aafad4ee4acf5ea232a5aa5f767877237db...  2019-02-22 03:21:39
# 89     40d58c0fd8b2249a8759418a61f7fb97bfd857edfae4d9...  2019-02-23 05:00:30
# 94     97ee1568136dde752d5d6d9f1c64d1e368d3a060246732...  2019-02-23 09:06:19
# 98     d344e1c3d0313efbdffc363d91e8342dcb56ca199ca290...  2019-02-23 10:11:00
# 100    a1de5e094330672b35dd2f89827649bac9f64ecd5777de...  2019-02-23 11:04:25
# ...                                                  ...                  ...
# 15130  e13eff18a2faa1640ebfdd6af5b2f2fd11dcfe1d7fd58f...  2020-03-06 10:53:16
# 15131  e13eff18a2faa1640ebfdd6af5b2f2fd11dcfe1d7fd58f...  2020-03-06 10:57:19
# 15134  53fc7be9f584c15718528862984e563568fac7cf72183d...  2020-03-13 12:37:30
# 15135  f283497b15d2cefc4507a5d65f90a4bc5effcab4e83ef4...  2020-03-13 12:43:15
# 15136  ad167e78bfc498d2e4a57fd1b1940c612500ada05667d3...  2020-03-14 00:33:27
#
#       event_type organization_type     event_category   user_type  \
# 46         Movie           Cinemas  Movies or Cinemas       Guest
# 89         Movie           Cinemas  Movies or Cinemas       Guest
# 94         Movie           Cinemas  Movies or Cinemas       Guest
# 98         Movie           Cinemas  Movies or Cinemas       Guest
# 100        Movie           Cinemas  Movies or Cinemas       Guest
# ...          ...               ...                ...         ...
# 15130      Movie           Cinemas  Movies or Cinemas       Guest
# 15131      Movie           Cinemas  Movies or Cinemas       Guest
# 15134      Movie           Cinemas  Movies or Cinemas  Registered
# 15135      Movie           Cinemas  Movies or Cinemas  Registered
# 15136      Movie           Cinemas  Movies or Cinemas  Registered
#
#       user_location  gender  age_when_register  price  total_ticket_sold
# 46              NaN    none                NaN  40000                  2
# 89              NaN    none                NaN  75000                  2
# 94              NaN    none                NaN  45000                  2
# 98              NaN    none                NaN  50000                  2
# 100             NaN     NaN                NaN  45000                  2
# ...             ...     ...                ...    ...                ...
# 15130           NaN    none                NaN  55000                  2
# 15131           NaN    none                NaN  55000                  2
# 15134           NaN  female               39.0  62500                  2
# 15135           NaN  female               39.0  47500                  2
# 15136           NaN    male               19.0  57500                  2
#
# [4681 rows x 12 columns]

# %%
df[df['user_location'].isna()]['user_type'].value_counts()
# Out:
# Guest         2830
# Registered    1851
# Name: user_type, dtype: int64

# %%
loc_regist_isna = df[(df['user_location'].isna()) & (df['user_type']=='Registered')]
loc_regist_notna = df[(df['user_location'].notna()) & (df['user_type']=='Registered')]

# %%
loc_regist_isna.head()
# Out:
#                                                 user_id  \
# 1042  ae4d632899331f334565b9b81629f0395abcab838bb91d...
# 1059  ae4d632899331f334565b9b81629f0395abcab838bb91d...
# 3136  7d55d8e8a3a007bf5ccf405ec1cd5e87483fecfc07b4a9...
# 5312  756f458f44b4c047ed31e9346a2e804d13488cd1badd82...
# 5317  756f458f44b4c047ed31e9346a2e804d13488cd1badd82...
#
#                                                event_id     transaction_date  \
# 1042  a8955367f9abec178f005bdad41c1988f70d7b48480539...  2019-05-08 05:56:49
# 1059  deb7319effac93639b51eadd87fe1ae35fe1085b32cc55...  2019-05-16 05:42:22
# 3136  2f061efe793c19c7c4d183d0ef9fb0030cac9463e66446...  2019-11-07 06:27:30
# 5312  c41d40719d214a3a52f56c4e8d252317814c0565e6707c...  2019-11-08 09:10:50
# 5317  4f22a24f4a48e420394f4a70558815d90013d4cd8409e2...  2019-11-08 09:27:25
#
#      event_type organization_type     event_category   user_type  \
# 1042      Movie           Cinemas  Movies or Cinemas  Registered
# 1059      Movie           Cinemas  Movies or Cinemas  Registered
# 3136      Movie           Cinemas  Movies or Cinemas  Registered
# 5312      Movie           Cinemas  Movies or Cinemas  Registered
# 5317      Movie           Cinemas  Movies or Cinemas  Registered
#
#      user_location  gender  age_when_register  price  total_ticket_sold
# 1042           NaN    male               19.0  42500                  2
# 1059           NaN    male               19.0  42500                  2
# 3136           NaN    male               21.0  35000                  1
# 5312           NaN  female               22.0  35000                  1
# 5317           NaN  female               22.0  35000                  1

# %%
loc_regist_notna.groupby('event_id')['user_location'].value_counts()
# Out:
# event_id                                                          user_location
# 000c00e8322eb941989528878f01f6add536a8605fbc0ce7b51d435257950ae0  Bandung          1
# 001ddd446a41b0fc4578b077b57f7c51faf3fe0d420eaa4ac256f4427c5fb765  Solo             1
# 0021a23a1ad6542f63317318470cf33a00d9bb97fc28c5bee08ab94ceb898cb1  Jakarta          1
# 00529ed280a461499121dfe398548b5f8abe8931cd8370f9480a0cc16d3fea51  Karawang         1
# 0052b33771d32eb1cb5585f030e6ca9b9b937ada33c26786f28258cc48fd8c9b  Purwakarta       1
#                                                                                   ..
# ffbdae7028c8079b6f6d9e643cdfc6fbd2b532649f759e6f6186a2a76e1f6fe8  Medan            1
# ffcb2a5a0c81b060ec7718c995054191462b77ad36e0525591a92d6fc289144f  Bandung          1
# ffd45f9312cc2c9758c74def3d4181451d750dc3141e5679ff2686eb7acf128d  Tangerang        1
# fff6b720244784039b5c481df195b63b0def753a5011bdee44f3cf535f5a5220  Blitar           1
# fffe648ef4d74ac326dbb995d3c282960ec78c26aacea5cfb6193e96560bf039  Pekanbaru        1
# Name: user_location, Length: 5080, dtype: int64

# %%
df[df['event_id']=='0021a23a1ad6542f63317318470cf33a00d9bb97fc28c5bee08ab94ceb898cb1']
# Out:
#                                                 user_id  \
# 1023  97a2b0837b6bd4201cff410dbd4d242bb8992d24c305b0...
#
#                                                event_id     transaction_date  \
# 1023  0021a23a1ad6542f63317318470cf33a00d9bb97fc28c5...  2019-04-30 07:37:32
#
#      event_type organization_type     event_category   user_type  \
# 1023      Movie           Cinemas  Movies or Cinemas  Registered
#
#      user_location gender  age_when_register  price  total_ticket_sold
# 1023       Jakarta   male               33.0  75000                  4

# %%
loc_regist_isna[loc_regist_isna['user_location'].isin(loc_regist_notna['user_location'])]
# Out:
# Empty DataFrame
# Columns: [user_id, event_id, transaction_date, event_type, organization_type, event_category, user_type, user_location, gender, age_when_register, price, total_ticket_sold]
# Index: []

# %% [markdown]
# > I think it's rather difficult to fill user location with no lead whatsoever. Therefore I'll fill these null values as **Unknown**.

# %%
df['user_location'].fillna('Unknown', inplace=True)

# %%
df.isna().sum()
# Out:
# user_id                 0
# event_id                0
# transaction_date        0
# event_type              0
# organization_type       0
# event_category          0
# user_type               0
# user_location           0
# gender                 23
# age_when_register    2882
# price                   0
# total_ticket_sold       0
# dtype: int64

# %% [markdown]
# > Now moving to **gender**.

# %%
df[df['gender'].isna()]
# Out:
#                                                  user_id  \
# 100    a0145331389e0662f4c99950648bad94da75583d354377...
# 858    fed7fa12df6ff811b748e624f7177ad8d4ed4c2a75b49e...
# 7594   ae72051054c987c1aca286cd33d9081d34f6ba284693ba...
# 9773   78310f1b44b7e2edd0e61b0cc54de97e58ab35df437f2a...
# 9832   78310f1b44b7e2edd0e61b0cc54de97e58ab35df437f2a...
# 13726  ca7e910f39fa0c5cfc13ce6da2908c5dc44383cd0e5dfd...
# 13728  ca7e910f39fa0c5cfc13ce6da2908c5dc44383cd0e5dfd...
# 13730  ca7e910f39fa0c5cfc13ce6da2908c5dc44383cd0e5dfd...
# 13732  ca7e910f39fa0c5cfc13ce6da2908c5dc44383cd0e5dfd...
# 13734  ca7e910f39fa0c5cfc13ce6da2908c5dc44383cd0e5dfd...
# 13736  ca7e910f39fa0c5cfc13ce6da2908c5dc44383cd0e5dfd...
# 13738  ca7e910f39fa0c5cfc13ce6da2908c5dc44383cd0e5dfd...
# 13970  ca7e910f39fa0c5cfc13ce6da2908c5dc44383cd0e5dfd...
# 13974  ca7e910f39fa0c5cfc13ce6da2908c5dc44383cd0e5dfd...
# 13977  ca7e910f39fa0c5cfc13ce6da2908c5dc44383cd0e5dfd...
# 13980  ca7e910f39fa0c5cfc13ce6da2908c5dc44383cd0e5dfd...
# 13983  ca7e910f39fa0c5cfc13ce6da2908c5dc44383cd0e5dfd...
# 13987  ca7e910f39fa0c5cfc13ce6da2908c5dc44383cd0e5dfd...
# 13989  ca7e910f39fa0c5cfc13ce6da2908c5dc44383cd0e5dfd...
# 13991  ca7e910f39fa0c5cfc13ce6da2908c5dc44383cd0e5dfd...
# 13993  ca7e910f39fa0c5cfc13ce6da2908c5dc44383cd0e5dfd...
# 13996  ca7e910f39fa0c5cfc13ce6da2908c5dc44383cd0e5dfd...
# 14626  ca7e910f39fa0c5cfc13ce6da2908c5dc44383cd0e5dfd...
#
#                                                 event_id     transaction_date  \
# 100    a1de5e094330672b35dd2f89827649bac9f64ecd5777de...  2019-02-23 11:04:25
# 858    7c1be0c107214fce0b35d09b4647b588108aa2d25c6cf7...  2019-04-21 09:49:41
# 7594   40affd7b6039825eefbddaf2557d5358abfcb2d3e4a72d...  2019-11-21 08:06:15
# 9773   74d1b71fa7a7a7c15f33371cdd80d1ed0462a4c21d6965...  2019-04-20 08:33:27
# 9832   658866c9cd70c8ad55d34d5313913474227d67d076de7b...  2019-04-21 08:12:38
# 13726  1532bb3b327ee704d022769c499067b85d516a3a015e43...  2019-11-08 21:54:35
# 13728  c41d40719d214a3a52f56c4e8d252317814c0565e6707c...  2019-11-08 22:04:35
# 13730  99a4090c558c90f65dc22213c0da9580b33f2d10c35216...  2019-11-08 22:23:58
# 13732  bf005c92cdace85983e5c7e371bdf9cf9fa3f8d51677e0...  2019-11-08 23:02:39
# 13734  faaaa00886a475a0cf89eded054725faff88714c6d087f...  2019-11-08 23:07:19
# 13736  4f22a24f4a48e420394f4a70558815d90013d4cd8409e2...  2019-11-08 23:10:40
# 13738  a08a86eeded8d0fd3dac0a6c45b50b94dac34f281b516b...  2019-11-08 23:21:42
# 13970  2f061efe793c19c7c4d183d0ef9fb0030cac9463e66446...  2019-11-10 08:44:08
# 13974  a5ef84d1f31b4573e9706226d67b4bea1ca110f7383232...  2019-11-10 08:53:54
# 13977  f2e10a84bc034e6d8d518eb96237d1ccce78893fc02412...  2019-11-10 09:13:44
# 13980  615c21905d23197d99e21d8211f30821b923b3baf8b5ed...  2019-11-10 09:23:11
# 13983  b017fac78706b95e373caffd6d1e796e1519ff50ba47be...  2019-11-10 09:32:28
# 13987  13e77a9de1fe7d09ebffd767e312694761f1cb57b52c8a...  2019-11-10 09:39:02
# 13989  ba25a05d72f2e8c8222b77af2a34067d4472efa4c793ed...  2019-11-10 09:42:10
# 13991  2c38830e61ca2e27b475a5bce3e61638bc1b9f8c11dcb3...  2019-11-10 09:44:41
# 13993  4eb4bd36def6333557363f599355f16b864390a6c70f5d...  2019-11-10 09:56:13
# 13996  f2cdc33fa77f1f7261d1c6c154a70e5dbf9e644d78a960...  2019-11-10 09:58:38
# 14626  21f5b997a4ad6526af531f144fd481e6a4e33f7505118b...  2019-11-20 02:55:36
#
#       event_type organization_type     event_category user_type user_location  \
# 100        Movie           Cinemas  Movies or Cinemas     Guest       Unknown
# 858        Movie           Cinemas  Movies or Cinemas     Guest       Unknown
# 7594       Movie           Cinemas  Movies or Cinemas     Guest       Unknown
# 9773       Movie           Cinemas  Movies or Cinemas     Guest       Unknown
# 9832       Movie           Cinemas  Movies or Cinemas     Guest       Unknown
# 13726      Movie           Cinemas  Movies or Cinemas     Guest       Unknown
# 13728      Movie           Cinemas  Movies or Cinemas     Guest       Unknown
# 13730      Movie           Cinemas  Movies or Cinemas     Guest       Unknown
# 13732      Movie           Cinemas  Movies or Cinemas     Guest       Unknown
# 13734      Movie           Cinemas  Movies or Cinemas     Guest       Unknown
# 13736      Movie           Cinemas  Movies or Cinemas     Guest       Unknown
# 13738      Movie           Cinemas  Movies or Cinemas     Guest       Unknown
# 13970      Movie           Cinemas  Movies or Cinemas     Guest       Unknown
# 13974      Movie           Cinemas  Movies or Cinemas     Guest       Unknown
# 13977      Movie           Cinemas  Movies or Cinemas     Guest       Unknown
# 13980      Movie           Cinemas  Movies or Cinemas     Guest       Unknown
# 13983      Movie           Cinemas  Movies or Cinemas     Guest       Unknown
# 13987      Movie           Cinemas  Movies or Cinemas     Guest       Unknown
# 13989      Movie           Cinemas  Movies or Cinemas     Guest       Unknown
# 13991      Movie           Cinemas  Movies or Cinemas     Guest       Unknown
# 13993      Movie           Cinemas  Movies or Cinemas     Guest       Unknown
# 13996      Movie           Cinemas  Movies or Cinemas     Guest       Unknown
# 14626      Movie           Cinemas  Movies or Cinemas     Guest       Unknown
#
#       gender  age_when_register  price  total_ticket_sold
# 100      NaN                NaN  45000                  2
# 858      NaN                NaN  75000                  2
# 7594     NaN                NaN  35000                  1
# 9773     NaN                NaN  50000                  1
# 9832     NaN                NaN  50000                  1
# 13726    NaN                NaN  35000                  4
# 13728    NaN                NaN  35000                  4
# 13730    NaN                NaN  50000                  4
# 13732    NaN                NaN  35000                  4
# 13734    NaN                NaN  35000                  4
# 13736    NaN                NaN  35000                  4
# 13738    NaN                NaN  35000                  4
# 13970    NaN                NaN  35000                  4
# 13974    NaN                NaN  35000                  4
# 13977    NaN                NaN  35000                  4
# 13980    NaN                NaN  35000                  4
# 13983    NaN                NaN  35000                  4
# 13987    NaN                NaN  35000                  4
# 13989    NaN                NaN  35000                  4
# 13991    NaN                NaN  35000                  4
# 13993    NaN                NaN  35000                  4
# 13996    NaN                NaN  50000                  4
# 14626    NaN                NaN  35000                  4

# %%
df['gender'].isna().value_counts()
# Out:
# False    15115
# True        23
# Name: gender, dtype: int64

# %%
df.groupby('user_type')['gender'].value_counts()
# Out:
# user_type   gender
# Guest       none      2806
#             female       3
# Registered  female    6573
#             male      5686
#             none        47
# Name: gender, dtype: int64

# %%
df[df['gender'].isna()]['user_type'].value_counts()
# Out:
# Guest    23
# Name: user_type, dtype: int64

# %%
df[(df['user_type']=='Guest') & (df['gender'].isna())].head()
# Out:
#                                                 user_id  \
# 100   a0145331389e0662f4c99950648bad94da75583d354377...
# 858   fed7fa12df6ff811b748e624f7177ad8d4ed4c2a75b49e...
# 7594  ae72051054c987c1aca286cd33d9081d34f6ba284693ba...
# 9773  78310f1b44b7e2edd0e61b0cc54de97e58ab35df437f2a...
# 9832  78310f1b44b7e2edd0e61b0cc54de97e58ab35df437f2a...
#
#                                                event_id     transaction_date  \
# 100   a1de5e094330672b35dd2f89827649bac9f64ecd5777de...  2019-02-23 11:04:25
# 858   7c1be0c107214fce0b35d09b4647b588108aa2d25c6cf7...  2019-04-21 09:49:41
# 7594  40affd7b6039825eefbddaf2557d5358abfcb2d3e4a72d...  2019-11-21 08:06:15
# 9773  74d1b71fa7a7a7c15f33371cdd80d1ed0462a4c21d6965...  2019-04-20 08:33:27
# 9832  658866c9cd70c8ad55d34d5313913474227d67d076de7b...  2019-04-21 08:12:38
#
#      event_type organization_type     event_category user_type user_location  \
# 100       Movie           Cinemas  Movies or Cinemas     Guest       Unknown
# 858       Movie           Cinemas  Movies or Cinemas     Guest       Unknown
# 7594      Movie           Cinemas  Movies or Cinemas     Guest       Unknown
# 9773      Movie           Cinemas  Movies or Cinemas     Guest       Unknown
# 9832      Movie           Cinemas  Movies or Cinemas     Guest       Unknown
#
#      gender  age_when_register  price  total_ticket_sold
# 100     NaN                NaN  45000                  2
# 858     NaN                NaN  75000                  2
# 7594    NaN                NaN  35000                  1
# 9773    NaN                NaN  50000                  1
# 9832    NaN                NaN  50000                  1

# %%
df['gender'] = df['gender'].fillna('none')

# %%
df.isna().sum()
# Out:
# user_id                 0
# event_id                0
# transaction_date        0
# event_type              0
# organization_type       0
# event_category          0
# user_type               0
# user_location           0
# gender                  0
# age_when_register    2882
# price                   0
# total_ticket_sold       0
# dtype: int64

# %% [markdown]
# > Now to **age when register**.

# %%
df[df['age_when_register'].isna()]['user_type'].value_counts()
# Out:
# Guest         2832
# Registered      50
# Name: user_type, dtype: int64

# %%
df[df['age_when_register'].notna()]['user_type'].value_counts()
# Out:
# Registered    12256
# Name: user_type, dtype: int64

# %% [markdown]
# > From above information, we can see that every missing values in this category are dominated by the **Guest** users. We will try to explore and mitigate this below.

# %%
df[df['user_type']=='Registered'].groupby('age_when_register')['event_id'].value_counts()
# Out:
# age_when_register  event_id
# 9.0                2a97a01dc018b0f22f0ea10980bd9770aed9d336c630b5cd7cbcf7ee509faa0a    2
#                    f08be54309c7f86688252774f0626c22977993346451b4e98e67a1cb5e7a5a20    2
#                    fe89344cf250678cb14f8ae1a39cc04d95d5d88959bebd2203922841952bb649    2
#                    06cd3fac6a8acd2dccad695b512c92dd45fd8c3aa5868a78ecf6d09d147788ce    1
#                    07d0425ba9d303c49c176c68d480de8f79229d0bbd573a652c7c5d33d4dca289    1
#                                                                                       ..
# 65.0               69fe75ed7b6985ec63a3c04d38737448cbfbc64da10ae32f5bf3bc5d83ec9b04    1
# 67.0               a260924adcd2b33b81220b40b616ea3f8f58f53ee8877810a16439381f7050c8    1
# 68.0               9ef47c758fe7c23fc84dd41885c064ccee99511cb262a04e32380c07db847563    1
# 70.0               a260924adcd2b33b81220b40b616ea3f8f58f53ee8877810a16439381f7050c8    1
# 90.0               a5a824d4c48633aec0797b247f4f78f31b0026511ea4e26d08f748da7cacada0    1
# Name: event_id, Length: 6670, dtype: int64

# %% [markdown]
# > Seeing above data, it seems a little bit odd since there are user with and user with 9, 70 and 90 age. I'll try to explore it below.

# %%
df['age_when_register'].value_counts().head(20)
# Out:
# 49.0    1696
# 21.0    1365
# 22.0     914
# 20.0     863
# 25.0     718
# 19.0     705
# 24.0     689
# 26.0     660
# 23.0     658
# 18.0     562
# 27.0     475
# 28.0     385
# 29.0     308
# 30.0     225
# 13.0     214
# 17.0     206
# 31.0     166
# 32.0     147
# 33.0     136
# 38.0     101
# Name: age_when_register, dtype: int64

# %%
df['age_when_register'].value_counts(ascending=True).head(20)
# Out:
# 57.0     1
# 62.0     1
# 54.0     1
# 68.0     1
# 61.0     1
# 90.0     1
# 67.0     1
# 70.0     1
# 60.0     1
# 65.0     2
# 63.0     2
# 59.0     2
# 53.0     2
# 58.0     3
# 51.0     3
# 11.0     4
# 56.0     4
# 52.0     9
# 55.0    10
# 50.0    11
# Name: age_when_register, dtype: int64

# %%
df['age_when_register'].sort_values(ascending=False).head(15)
# Out:
# 50       90.0
# 9774     70.0
# 8820     68.0
# 807      67.0
# 726      65.0
# 32       65.0
# 2382     63.0
# 2013     63.0
# 2718     62.0
# 15089    61.0
# 2071     60.0
# 2367     59.0
# 171      59.0
# 10297    58.0
# 11145    58.0
# Name: age_when_register, dtype: float64

# %%
df['age_when_register'].sort_values(ascending=True).head(15)
# Out:
# 2463     9.0
# 800      9.0
# 2490     9.0
# 11243    9.0
# 406      9.0
# 10775    9.0
# 1202     9.0
# 1941     9.0
# 10894    9.0
# 10006    9.0
# 10005    9.0
# 2517     9.0
# 840      9.0
# 184      9.0
# 11004    9.0
# Name: age_when_register, dtype: float64

# %%
df[df['age_when_register']>65]
# Out:
#                                                 user_id  \
# 50    b767ab41e1191831cfc628570723d9df9d9027f8e99ad1...
# 807   b1687d163b8c7098e963b6016e67687905e6dba44bfb34...
# 8820  caa750287dc118fb0af5db8f3e14bf30eb0e317df5bf4a...
# 9774  893af0f16a3323bde1174b2befecdd75393d790656a020...
#
#                                                event_id     transaction_date  \
# 50    a5a824d4c48633aec0797b247f4f78f31b0026511ea4e2...  2019-02-22 04:03:12
# 807   a260924adcd2b33b81220b40b616ea3f8f58f53ee88778...  2019-04-20 08:30:40
# 8820  9ef47c758fe7c23fc84dd41885c064ccee99511cb262a0...  2020-01-31 10:46:43
# 9774  a260924adcd2b33b81220b40b616ea3f8f58f53ee88778...  2019-04-20 09:01:49
#
#      event_type organization_type     event_category   user_type  \
# 50        Movie           Cinemas  Movies or Cinemas  Registered
# 807       Movie           Cinemas  Movies or Cinemas  Registered
# 8820      Movie           Cinemas  Movies or Cinemas  Registered
# 9774      Movie           Cinemas  Movies or Cinemas  Registered
#
#      user_location  gender  age_when_register  price  total_ticket_sold
# 50         Bandung    male               90.0  40000                  2
# 807       Surabaya  female               67.0  50000                  1
# 8820       Unknown    male               68.0  42500                  2
# 9774      Surabaya    male               70.0  50000                  1

# %%
df[df['age_when_register']<10]
# Out:
#                                                  user_id  \
# 111    b23636f78956ef7d3b924619508ec40761217b04a81f89...
# 128    a2728415e009ed304106953af0279da024cdaab423a233...
# 184    49a2258de669dfb579987f31a6672955e3ebd65a8369bf...
# 406    cec853fe1296ed7c1f6d3687b0de5947a2e26aabb793bd...
# 424    1411aa4324bea632dc0b70bd0d9dae6257eec11b4be8be...
# ...                                                  ...
# 14805  2e31eb80515999393fd6ebcbe9726d872b7b949bd55281...
# 14806  2e31eb80515999393fd6ebcbe9726d872b7b949bd55281...
# 14807  2e31eb80515999393fd6ebcbe9726d872b7b949bd55281...
# 14809  2e31eb80515999393fd6ebcbe9726d872b7b949bd55281...
# 14880  4dea03296b9088e2fe53a84b9859295352ccd2ac343e64...
#
#                                                 event_id     transaction_date  \
# 111    2a97a01dc018b0f22f0ea10980bd9770aed9d336c630b5...  2019-02-24 04:07:52
# 128    ae4ad8867966d64952ff5923f3308caa5076494c607cac...  2019-02-24 15:40:21
# 184    c4f2037e66f080ab370d86022ace29db176fdcf041897f...  2019-02-25 11:36:55
# 406    b609fe1607357e28371b3db4d2473b394d3efe8f5d8f4c...  2019-02-27 12:26:54
# 424    e49694caa9bf4119f97bbb5a9d60c3f22ed1749c7f43f5...  2019-02-27 13:51:56
# ...                                                  ...                  ...
# 14805  ded63d1e197eed5285c268ce13416f65aadcde802819b5...  2019-11-21 11:08:20
# 14806  615c21905d23197d99e21d8211f30821b923b3baf8b5ed...  2019-11-21 11:20:41
# 14807  cd322f8574685973984f6ad1e1192a0ba5e49ce7181937...  2019-11-21 11:22:44
# 14809  99a4090c558c90f65dc22213c0da9580b33f2d10c35216...  2019-11-21 11:30:03
# 14880  205edc653aca9912d28637b80c666c1530f76707411bfe...  2019-11-22 06:05:54
#
#       event_type organization_type     event_category   user_type  \
# 111        Movie           Cinemas  Movies or Cinemas  Registered
# 128        Movie           Cinemas  Movies or Cinemas  Registered
# 184        Movie           Cinemas  Movies or Cinemas  Registered
# 406        Movie           Cinemas  Movies or Cinemas  Registered
# 424        Movie           Cinemas  Movies or Cinemas  Registered
# ...          ...               ...                ...         ...
# 14805      Movie           Cinemas  Movies or Cinemas  Registered
# 14806      Movie           Cinemas  Movies or Cinemas  Registered
# 14807      Movie           Cinemas  Movies or Cinemas  Registered
# 14809      Movie           Cinemas  Movies or Cinemas  Registered
# 14880      Movie           Cinemas  Movies or Cinemas  Registered
#
#       user_location  gender  age_when_register  price  total_ticket_sold
# 111       Palembang    male                9.0  35000                  2
# 128      Purwokerto  female                9.0  30000                  2
# 184      Yogyakarta    male                9.0  30000                  2
# 406          Bekasi    male                9.0  30000                  2
# 424       Palembang    male                9.0  35000                  2
# ...             ...     ...                ...    ...                ...
# 14805    Yogyakarta  female                9.0  35000                  1
# 14806    Yogyakarta  female                9.0  35000                  1
# 14807    Yogyakarta  female                9.0  35000                  1
# 14809    Yogyakarta  female                9.0  50000                  1
# 14880      Surabaya    male                9.0  35000                  1
#
# [76 rows x 12 columns]

# %%
df.groupby('event_id')['age_when_register'].value_counts()
# Out:
# event_id                                                          age_when_register
# 000c00e8322eb941989528878f01f6add536a8605fbc0ce7b51d435257950ae0  19.0                 1
# 001ddd446a41b0fc4578b077b57f7c51faf3fe0d420eaa4ac256f4427c5fb765  21.0                 1
# 0021a23a1ad6542f63317318470cf33a00d9bb97fc28c5bee08ab94ceb898cb1  33.0                 1
# 00529ed280a461499121dfe398548b5f8abe8931cd8370f9480a0cc16d3fea51  12.0                 1
# 0052b33771d32eb1cb5585f030e6ca9b9b937ada33c26786f28258cc48fd8c9b  20.0                 1
#                                                                                       ..
# ffbdae7028c8079b6f6d9e643cdfc6fbd2b532649f759e6f6186a2a76e1f6fe8  23.0                 1
# ffcb2a5a0c81b060ec7718c995054191462b77ad36e0525591a92d6fc289144f  21.0                 1
# ffd45f9312cc2c9758c74def3d4181451d750dc3141e5679ff2686eb7acf128d  24.0                 1
# fff6b720244784039b5c481df195b63b0def753a5011bdee44f3cf535f5a5220  29.0                 1
# fffe648ef4d74ac326dbb995d3c282960ec78c26aacea5cfb6193e96560bf039  23.0                 1
# Name: age_when_register, Length: 6670, dtype: int64

# %%
age_isna = df[df['age_when_register'].isna()]
age_notna = df[df['age_when_register'].notna()]

# %%
age_notna.groupby('event_id')['age_when_register'].value_counts().head(30)
# Out:
# event_id                                                          age_when_register
# 000c00e8322eb941989528878f01f6add536a8605fbc0ce7b51d435257950ae0  19.0                 1
# 001ddd446a41b0fc4578b077b57f7c51faf3fe0d420eaa4ac256f4427c5fb765  21.0                 1
# 0021a23a1ad6542f63317318470cf33a00d9bb97fc28c5bee08ab94ceb898cb1  33.0                 1
# 00529ed280a461499121dfe398548b5f8abe8931cd8370f9480a0cc16d3fea51  12.0                 1
# 0052b33771d32eb1cb5585f030e6ca9b9b937ada33c26786f28258cc48fd8c9b  20.0                 1
# 00560397c680d37c75926112df54dfb06ee38d08f09ddf055e246ce662f650fc  24.0                 1
# 0069a295cb6c8436cf51728552bc9bf487a73b6a0ef4b3141b480c419e145631  19.0                 1
#                                                                   22.0                 1
# 00863f9acccb75ecd72389e5f9bfc5096f5d8328a6c207d322781c1704ac1cae  31.0                 1
# 0092a60331bf5a4903dc9e09f2413fece4e8421ac251ce5caf56c57378ad4fbe  21.0                 1
# 009632db45228c03be6f143059f75c10e7fb8ee372845273daa09d8cea3ae6ef  27.0                 1
# 00f0207fa828ea9ef79d6da66e887518dfe039183b5a69f4c47df4c4a8959993  27.0                 2
# 00f819eae281c59c12cacab0ac23a98d1d7830274c5d2a582a542907c6363288  24.0                 1
# 01127fc68bce04f0360caf6bc9a76e15644abe884dbb45fb39b26c6facdc7420  20.0                 1
# 01171c8f622c44f609b95fcc6a81e087da299ed4bb6100748807be26eb6ec2a7  19.0                 1
# 011b633f64247a441b5c44bcd45c2cd4fb45f4917aa1cd2eb96e6dc2dd419537  20.0                 1
# 0122d709c7b1752c0539fb2f7bf8b9e643d8dbd31563ce6d3b98456baef966a0  20.0                 1
# 01235b96f85d24dd7864aa131ff8b99cfb8a32e5e8118433c5e57dcbfce702be  17.0                 1
#                                                                   23.0                 1
# 01238d00e911ef3f4b4f3c0e5bddccd916ecdb6af03dcfe4bc061ed2ad6c0182  19.0                 1
# 0130528e715422305267bcbac4ff8be3064a5bf2c2fc0c493a7031e0f2831513  25.0                 1
# 01450d190826f3bbd8bb1b5e1a6124fdc81fc384e037c31ebca52ddd1f43cdfa  24.0                 1
# 014ac8c8379486e37c19b907d956224e2480fc5c168672d3c91e670c420fc159  32.0                 1
# 01622e82c0ed06e5442a3938e2f39d9a3edf6a61d32fdfcfeb477d34d448b502  36.0                 1
# 01715142dc34c02b2fffc48604cd8f3c58904dfbb6c21faa4f461494e295eca3  20.0                 1
# 0177e7ab6605164295b7207d0f0c3b2ebfef929e91d2c1535234edbce2796fe3  21.0                 1
# 0184193fb91f53c913c6d7524bb47d12b2e9055f86a7d912c1494d6dd4e0c6a5  39.0                 1
# 019fd4bdd3b3c2fadbcdf5c28fb16dbc520e908694390a9d42d5b620f455d68d  33.0                 1
# 01b6127671e6bfe5779f960ac37c61e43291a20e6404621029579eb9c9978efd  32.0                 1
# 01d003e57842162c610c5e96a6eb1a868f6c5e37620cbd0e047a543bcc9d7db5  20.0                 1
# Name: age_when_register, dtype: int64

# %%
age_isna[age_isna['event_id'].isin(age_notna['event_id'])]
# Out:
#                                                  user_id  \
# 94     97f0e8938bbfe3e6245fee82693ae69577545ac12c4f90...
# 103    2143f75c413d717ea7801ae7f5f5c00afbf2fe59ad226c...
# 124    e79876d65d2e076896edf083a73cc17908372afd55c4f4...
# 154    4f5ec2fdc796bc665a9714900882b4c379a21f98e95b0e...
# 155    b81ec1fc08c1dd6c7db2f655b94ab61b9552d43d49dd1d...
# ...                                                  ...
# 14950  5dd3d1b6c042caaea56f4415b38a7ef8a59ac39b918e14...
# 14951  42c3e23b53b620239bd38e1bca32cb3581ee7c0e2a4633...
# 14956  8fbccc99b8d21dd7966ae60d6c0548671ccbb99aa781cc...
# 14958  497c731a86ede5e072472b333b62b0e8320b2b7c2c0620...
# 14959  27a7473832a93f7dcf28fa0c955794bbae30f2c64255e4...
#
#                                                 event_id     transaction_date  \
# 94     97ee1568136dde752d5d6d9f1c64d1e368d3a060246732...  2019-02-23 09:06:19
# 103    89f275a18d3434f69efe7e6d07726199bf8053e312b3bb...  2019-02-23 12:17:43
# 124    bda11b0424bf6bab9363b1a984d112f7e15a22d4336922...  2019-02-24 11:43:06
# 154    31d10df6079307172dac092d0de192cbabe339748153cd...  2019-02-25 05:47:12
# 155    31d10df6079307172dac092d0de192cbabe339748153cd...  2019-02-25 05:49:59
# ...                                                  ...                  ...
# 14950  99a4090c558c90f65dc22213c0da9580b33f2d10c35216...  2019-11-23 05:48:32
# 14951  41643007db28aa053900e2d6b38b5ae6fd86e67cae9f1a...  2019-11-23 05:58:17
# 14956  cd322f8574685973984f6ad1e1192a0ba5e49ce7181937...  2019-11-23 06:58:52
# 14958  0aceac5989647d09420a7c7d12691ec40c27cb3813b1bc...  2019-11-23 07:15:04
# 14959  2c38830e61ca2e27b475a5bce3e61638bc1b9f8c11dcb3...  2019-11-23 07:16:15
#
#       event_type organization_type     event_category user_type user_location  \
# 94         Movie           Cinemas  Movies or Cinemas     Guest       Unknown
# 103        Movie           Cinemas  Movies or Cinemas     Guest       Unknown
# 124        Movie           Cinemas  Movies or Cinemas     Guest       Unknown
# 154        Movie           Cinemas  Movies or Cinemas     Guest       Unknown
# 155        Movie           Cinemas  Movies or Cinemas     Guest       Unknown
# ...          ...               ...                ...       ...           ...
# 14950      Movie           Cinemas  Movies or Cinemas     Guest       Unknown
# 14951      Movie           Cinemas  Movies or Cinemas     Guest       Unknown
# 14956      Movie           Cinemas  Movies or Cinemas     Guest       Unknown
# 14958      Movie           Cinemas  Movies or Cinemas     Guest       Unknown
# 14959      Movie           Cinemas  Movies or Cinemas     Guest       Unknown
#
#       gender  age_when_register  price  total_ticket_sold
# 94      none                NaN  45000                  2
# 103     none                NaN  35000                  2
# 124     none                NaN  35000                  2
# 154     none                NaN  35000                  2
# 155     none                NaN  35000                  2
# ...      ...                ...    ...                ...
# 14950   none                NaN  50000                  1
# 14951   none                NaN  35000                  1
# 14956   none                NaN  35000                  1
# 14958   none                NaN  35000                  1
# 14959   none                NaN  35000                  2
#
# [2202 rows x 12 columns]

# %%
age = age_notna[age_notna['event_id'].isin(age_isna['event_id'])]

# %%
age['event_id'].value_counts().head(10)
# Out:
# f2e10a84bc034e6d8d518eb96237d1ccce78893fc024127b004041bfe37c1804    143
# c71952786040a4b56ac78f3bd22b8608e4b32da54b457fc9aa392f8f598a8552    136
# 939cc358d7225da272f0cb95bb587893ad86f810751b688aa0c2bde5cd8a1181    134
# c41d40719d214a3a52f56c4e8d252317814c0565e6707c570c230f5e4b8ac14e    129
# 388f0a9896b88bd58dbc24d7060887bc808a3e6743a7a8d4b9bbfb382b3e1d6f    121
# d1df2753a4c0408015cbc3d95cc640005104b17b45c7faf7f51ef235519a6171    118
# fe88240ce66b31fd90245a0e19268c814b7255e29ce3a6fcfe204ecdc28e6bf0    116
# faaaa00886a475a0cf89eded054725faff88714c6d087f41ba616940e5d67ed5    116
# bf005c92cdace85983e5c7e371bdf9cf9fa3f8d51677e08a03131d588783089c    113
# 1532bb3b327ee704d022769c499067b85d516a3a015e43beafd127c3b4e3acea    109
# Name: event_id, dtype: int64

# %%
# Locating event_id

age_mov1 = age_isna[age_isna['event_id'] == 'f2e10a84bc034e6d8d518eb96237d1ccce78893fc024127b004041bfe37c1804']
age_mov2 = age_isna[age_isna['event_id'] == 'c71952786040a4b56ac78f3bd22b8608e4b32da54b457fc9aa392f8f598a8552']
age_mov3 = age_isna[age_isna['event_id'] == '939cc358d7225da272f0cb95bb587893ad86f810751b688aa0c2bde5cd8a1181']
age_mov4 = age_isna[age_isna['event_id'] == 'c41d40719d214a3a52f56c4e8d252317814c0565e6707c570c230f5e4b8ac14e']
age_mov5 = age_isna[age_isna['event_id'] == '388f0a9896b88bd58dbc24d7060887bc808a3e6743a7a8d4b9bbfb382b3e1d6f']
age_mov6 = age_isna[age_isna['event_id'] == 'd1df2753a4c0408015cbc3d95cc640005104b17b45c7faf7f51ef235519a6171']
age_mov7 = age_isna[age_isna['event_id'] == 'faaaa00886a475a0cf89eded054725faff88714c6d087f41ba616940e5d67ed5']
age_mov8 = age_isna[age_isna['event_id'] == 'fe88240ce66b31fd90245a0e19268c814b7255e29ce3a6fcfe204ecdc28e6bf0']
age_mov9 = age_isna[age_isna['event_id'] == 'bf005c92cdace85983e5c7e371bdf9cf9fa3f8d51677e08a03131d588783089c']
age_mov10 = age_isna[age_isna['event_id'] == '1532bb3b327ee704d022769c499067b85d516a3a015e43beafd127c3b4e3acea']

# %%
# Measure filled values

age_fill1 = round(age[age['event_id']=='f2e10a84bc034e6d8d518eb96237d1ccce78893fc024127b004041bfe37c1804']['age_when_register'].mean())
age_fill2 = round(age[age['event_id']=='c71952786040a4b56ac78f3bd22b8608e4b32da54b457fc9aa392f8f598a8552']['age_when_register'].mean())
age_fill3 = round(age[age['event_id']=='939cc358d7225da272f0cb95bb587893ad86f810751b688aa0c2bde5cd8a1181']['age_when_register'].mean())
age_fill4 = round(age[age['event_id']=='c41d40719d214a3a52f56c4e8d252317814c0565e6707c570c230f5e4b8ac14e']['age_when_register'].mean())
age_fill5 = round(age[age['event_id']=='388f0a9896b88bd58dbc24d7060887bc808a3e6743a7a8d4b9bbfb382b3e1d6f']['age_when_register'].mean())
age_fill6 = round(age[age['event_id']=='d1df2753a4c0408015cbc3d95cc640005104b17b45c7faf7f51ef235519a6171']['age_when_register'].mean())
age_fill7 = round(age[age['event_id']=='faaaa00886a475a0cf89eded054725faff88714c6d087f41ba616940e5d67ed5']['age_when_register'].mean())
age_fill8 = round(age[age['event_id']=='fe88240ce66b31fd90245a0e19268c814b7255e29ce3a6fcfe204ecdc28e6bf0']['age_when_register'].mean())
age_fill9 = round(age[age['event_id']=='bf005c92cdace85983e5c7e371bdf9cf9fa3f8d51677e08a03131d588783089c']['age_when_register'].mean())
age_fill10 = round(age[age['event_id']=='1532bb3b327ee704d022769c499067b85d516a3a015e43beafd127c3b4e3acea']['age_when_register'].mean())

# %%
# Filling missing value

age_mov1['age_when_register'] = age_mov1['age_when_register'].fillna(age_fill1)
age_mov2['age_when_register'] = age_mov2['age_when_register'].fillna(age_fill2)
age_mov3['age_when_register'] = age_mov3['age_when_register'].fillna(age_fill3)
age_mov4['age_when_register'] = age_mov4['age_when_register'].fillna(age_fill4)
age_mov5['age_when_register'] = age_mov5['age_when_register'].fillna(age_fill5)
age_mov6['age_when_register'] = age_mov6['age_when_register'].fillna(age_fill6)
age_mov7['age_when_register'] = age_mov7['age_when_register'].fillna(age_fill7)
age_mov8['age_when_register'] = age_mov8['age_when_register'].fillna(age_fill8)
age_mov9['age_when_register'] = age_mov9['age_when_register'].fillna(age_fill9)
age_mov10['age_when_register'] = age_mov10['age_when_register'].fillna(age_fill10)

# %%
age_filled = pd.concat([age_mov1, age_mov2, age_mov3, age_mov4, age_mov5, age_mov6, age_mov7, age_mov8, age_mov9, age_mov10])

# %%
age_isna['age_when_register'] = age_isna['age_when_register'].fillna(age_filled['age_when_register'])

# %%
age_fill = pd.concat([age_isna, age_notna])

# %%
# Merging to original dataframe

df['age_when_register'] = df['age_when_register'].fillna(age_fill['age_when_register'])

# %%
df.isna().sum()
# Out:
# user_id                 0
# event_id                0
# transaction_date        0
# event_type              0
# organization_type       0
# event_category          0
# user_type               0
# user_location           0
# gender                  0
# age_when_register    2363
# price                   0
# total_ticket_sold       0
# dtype: int64

# %%
df[df['user_type']=='Guest']['age_when_register'].median()
# Out:
# 24.0

# %%
df['age_when_register'] = df['age_when_register'].fillna(24)

# %%
pd.DataFrame({'dataFeatures' : df.columns, 'dataType' : df.dtypes.values, 
              'null' : [df[i].isna().sum() for i in df.columns],
              'nullPct' : [((df[i].isna().sum()/len(df[i]))*100).round(1) for i in df.columns],
              'Nunique' : [df[i].nunique() for i in df.columns],
              'uniqueSample' : [list(pd.Series(df[i].unique()).sample()) for i in df.columns]}).reset_index(drop = True)
# Out:
#          dataFeatures dataType  null  nullPct  Nunique  \
# 0             user_id   object     0      0.0     5038
# 1            event_id   object     0      0.0     5289
# 2    transaction_date   object     0      0.0    14945
# 3          event_type   object     0      0.0        1
# 4   organization_type   object     0      0.0        1
# 5      event_category   object     0      0.0        1
# 6           user_type   object     0      0.0        2
# 7       user_location   object     0      0.0       31
# 8              gender   object     0      0.0        3
# 9   age_when_register  float64     0      0.0       60
# 10              price    int64     0      0.0       41
# 11  total_ticket_sold    int64     0      0.0        8
#
#                                          uniqueSample
# 0   [819ef1a9ae7999adedfb1ea4d75fd1d920b07e703bc0c...
# 1   [1a52d32d603962e8288a40f072b9cd34b92e1508bdec5...
# 2                               [2019-07-15 05:58:55]
# 3                                             [Movie]
# 4                                           [Cinemas]
# 5                                 [Movies or Cinemas]
# 6                                             [Guest]
# 7                                         [Mojokerto]
# 8                                            [female]
# 9                                              [41.0]
# 10                                           [100000]
# 11                                                [5]

# %%
df.to_csv('dataset\movie_clean.csv', index=False)
